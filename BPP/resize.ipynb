# %%
import os
import csv
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# %%
os.getcwd()
path='./SKR-HEX-20221116/noangle/'

# %%
img = cv2.imread(path+'DSC05956.JPG')
print(img.shape)
img = img[1800:4500,1400:4100]
#img = cv2.resize(img, (2400,2400))
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imwrite('test.JPG',img)
print(img.shape)
plt.imshow(img)
# Out:
# (5760, 5760, 3)
# (2700, 2700)

# %%
img_flip_along_x = cv2.flip(img, 0)
cv2.imwrite('./SKR-HEX-20221116/cropped/xy-DSC03370.JPG',img)
# Out:
# True

# %% [markdown]
# ## resize Picture

# %%
for name in os.listdir(path):
    img = cv2.imread(path+name)
    img = img[1800:4500,1400:4100] #Y,X
    img = cv2.resize(img, (1200,1200))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    cv2.imwrite('./SKR-HEX-20221116/noangle_cropped-1200/'+name,img)

# %% [markdown]
# # flip pic

# %%
path='./SKR-HEX-20221116/cropped/'
for name in os.listdir(path):
    img = cv2.imread(path+name)
    img_flip_along_x = cv2.flip(img, 0)
    img_flip_along_y = cv2.flip(img, 1)
    img_flip_along_xy = cv2.flip(img, -1)
    cv2.imwrite('./SKR-HEX-20221116/cropped/flip/x'+name,img_flip_along_x)
    cv2.imwrite('./SKR-HEX-20221116/cropped/flip/y'+name,img_flip_along_y)
    cv2.imwrite('./SKR-HEX-20221116/cropped/flip/xy'+name,img_flip_along_xy)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# f:\database\Bolt_preload\resize.ipynb Cell 8 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/f%3A/database/Bolt_preload/resize.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> img_flip_along_y = cv2.flip(img, 1)
#       <a href='vscode-notebook-cell:/f%3A/database/Bolt_preload/resize.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> img_flip_along_xy = cv2.flip(img, -1)
# ----> <a href='vscode-notebook-cell:/f%3A/database/Bolt_preload/resize.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> cv2.imwrite('./SKR-HEX-20221116/cropped/flip/x'+name,img_flip_along_x)
#       <a href='vscode-notebook-cell:/f%3A/database/Bolt_preload/resize.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> cv2.imwrite('./SKR-HEX-20221116/cropped/flip/y'+name,img_flip_along_y)
# ...

# %%
f=open('label.csv','w')
for name in os.listdir('./20221110-tcobolt-row/'):
    a=os.path.splitext(name)[0]
    a=a.split('-')[1]
    f.write(a+'\n')
f.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       2 for name in os.listdir('./20221110-tcobolt-row/'):
#       3     a=os.path.splitext(name)[0]
# ----> 4     a=a.split('-')[1]
#       5     f.write(a+'\n')
#       6 f.close()
#
# IndexError: list index out of range

# %%
i=[]
for name in os.listdir(path):
    a=os.path.splitext(name)[0]
    i.append(a)

j=0
for name in os.listdir('./rowdata/'):
    os.rename('./rowdata/'+name,'./rowdata/'+i[j]+'.JPG')
    j+=1
