# %%
import pandas as pd
import torch
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import TensorDataset, DataLoader
import os
import cv2 as cv
from torch.utils.data import Dataset
from torchvision import transforms
import torch.nn.functional as F
from PIL import Image
import torch.nn as nn
from torch.optim import Adam
import matplotlib.pyplot as plt
import numpy as np
from torch.autograd import Variable

# %% [markdown]
# # Define the data and label

# %%
def getlabel(dir):
    labels=[]
    for name in os.listdir(dir):
        if os.path.splitext(name)[1] == '.JPG':
            fname=os.path.splitext(name)[0]
            fname=fname.split('-')[1]
            labels.append(fname)
    labels = list(map(float, labels))
    labels = torch.tensor(labels)
    # Normalize labels
    #min = torch.min(labels)
    #max = torch.max(labels)
    #labels = (labels - min) / (max - min)
    labels = labels.type(torch.FloatTensor)
    labels = labels.unsqueeze(1)
    return labels

def generate_dataset(dir):
    """
    set_label should be 'torch.tensor([1])' if two-catogory and positive sample
    """
    train_data = []
    for file_name in os.listdir(dir):
        if file_name != "Thumbs.db":
            img_dir = os.path.join(dir, file_name)
            img = cv.imread(img_dir)
            #img = cv.resize(img, (769, 432))   # /5 resize img
            #img_gray = cv.cvtColor(img,cv.COLOR_RGB2GRAY)
            pimg = Image.fromarray(img)
            train_data.append(pimg)
    return train_data

# %%
traindir= './train/'
validdir = './valid/'
train_data0 = generate_dataset(traindir)
train_label0=getlabel(traindir)
valid_data0 = generate_dataset(validdir)
valid_label0 = getlabel(validdir)

# %%
train_label0
# Out:
# tensor([[  0.0000],
#         [ 20.0000],
#         [ 28.0000],
#         [ 35.0000],
#         [ 37.0000],
#         [ 39.0000],
#         [ 42.0000],
#         [ 48.0000],
#         [ 51.0000],
#         [ 62.0000],
#         [ 72.0000],
#         [ 75.0000],
#         [ 81.0000],
#         [ 97.0000],
#         [ 96.0000],
#         [105.0000],
#         [111.0000],
#         [118.0000],
#         [124.0000],
#         [135.0000],
#         [140.0000],
#         [146.0000],
#         [154.0000],
#         [165.0000],
#         [161.0000],
#         [158.0000],
#         [154.0000],
#         [150.0000],
#         [146.0000],
#         [143.0000],
#         [138.0000],
#         [135.0000],
#         [133.0000],
#         [130.0000],
#         [127.0000],
#         [124.0000],
#         [122.0000],
#         [119.0000],
#         [116.0000],
#         [110.0000],
#         [107.0000],
#         [103.0000],
#         [ 96.0000],
#         [ 94.0000],
#         [ 92.0000],
#         [ 90.0000],
#         [ 86.0000],
#         [ 84.0000],
#         [ 81.0000],
#         [ 80.5000],
#         [ 79.0000],
#         [ 76.0000],
#         [ 74.0000],
#         [ 72.0000],
#         [ 68.0000],
#         [ 65.0000],
#         [ 63.0000],
#         [ 61.0000],
#         [ 59.5000],
#         [ 58.0000],
#         [ 56.5000],
#         [ 55.0000],
#         [ 52.0000],
#         [ 50.0000],
#         [ 49.5000],
#         [ 47.5000],
#         [ 45.5000],
#         [ 44.0000],
#         [ 42.0000],
#         [ 40.5000],
#         [ 38.0000],
#         [ 36.0000],
#         [ 33.0000],
#         [ 29.0000],
#         [ 27.0000],
#         [ 26.0000],
#         [  8.0000],
#         [ 25.0000],
#         [ 29.5000],
#         [ 35.5000],
#         [ 41.5000],
#         [ 45.5000],
#         [ 52.0000],
#         [ 59.0000],
#         [ 67.0000],
#         [ 77.0000],
#         [ 82.0000],
#         [ 85.0000],
#         [ 88.0000],
#         [ 91.0000],
#         [ 95.5000],
#         [ 99.0000],
#         [102.0000],
#         [108.0000],
#         [115.0000],
#         [120.0000],
#         [126.0000],
#         [132.0000],
#         [140.0000],
#         [144.5000],
#         [150.0000],
#         [155.0000],
#         [160.0000],
#         [165.5000],
#         [172.5000],
#         [178.0000],
#         [175.0000],
#         [170.0000],
#         [166.0000],
#         [164.0000],
#         [105.5000],
#         [150.5000],
#         [146.0000],
#         [140.5000],
#         [137.5000],
#         [133.0000],
#         [129.0000],
#         [124.0000],
#         [116.5000],
#         [113.5000],
#         [111.0000],
#         [108.0000],
#         [107.0000],
#         [100.0000],
#         [ 97.5000],
#         [ 95.0000],
#         [ 92.0000],
#         [ 90.0000],
#         [ 86.0000],
#         [ 83.0000],
#         [ 81.5000],
#         [ 78.0000],
#         [ 74.0000],
#         [ 72.0000],
#         [ 68.0000],
#         [ 66.0000],
#         [ 64.0000],
#         [ 61.0000],
#         [ 59.0000],
#         [ 56.5000],
#         [ 54.0000],
#         [ 49.5000],
#         [ 47.0000],
#         [ 45.0000],
#         [ 43.0000],
#         [ 40.0000],
#         [ 37.0000],
#         [ 34.0000],
#         [ 30.0000],
#         [ 28.0000],
#         [ 26.0000],
#         [ 24.5000],
#         [ 22.5000],
#         [ 20.5000]])

# %% [markdown]
# # 重写dataset类

# %%
class MyDataset(Dataset):
    def __init__(self, data, labels, transform=None, target_transform=None):
        self.transform = transform
        self.target_transform = target_transform
        imgs = []
        for i in range(len(labels)):
            # print(type(data[i]))    # <class 'PIL.Image.Image'>
            im_tensor = transform(data[i])#.to(torch.device("cpu"))
            imgs.append((im_tensor, labels[i]))
        self.imgs = imgs                         # DataLoader通过getitem读取图片数据
    def __getitem__(self, index):
        fn, label = self.imgs[index]
        return fn, label
    def __len__(self):
        return len(self.imgs)

# %% [markdown]
# # 用MyDataset构建数据集

# %%
normMean = [0.5, 0.5, 0.5]
normStd = [0.5, 0.5, 0.5]
transform = transforms.Compose(
    [transforms.Grayscale(num_output_channels=1), #彩色图像转灰度图像num_output_channels默认1
    transforms.ToTensor(),  # range [0, 255] -> [0.0,1.0]   
    #transforms.Normalize(normMean, normStd)
    ])

# 也可以再定义train_transform加入一些数据增强 
train_data = MyDataset(train_data0, train_label0, transform=transform)
valid_data = MyDataset(valid_data0, valid_label0, transform=transform)
train_loader = DataLoader(dataset=train_data, batch_size=5, shuffle=True)
valid_loader = DataLoader(dataset=valid_data, batch_size=5, shuffle=True)
dataiter=iter(train_loader)
images, labels = dataiter.next()
print(images.shape)
print(labels.shape)
# Out:
# torch.Size([5, 1, 2400, 2400])
# torch.Size([5, 1])

# %% [markdown]
# # 定义网络

# %%
class ResidualBlock(nn.Module):
    def __init__(self,channels):
        super(ResidualBlock,self).__init__()
        self.channels = channels
        self.conv1 = nn.Conv2d(channels,channels,kernel_size=3,padding=1)
        self.conv2 = nn.Conv2d(channels,channels,kernel_size=3,padding=1)
    
    def forward(self,x):
        y = F.relu(self.conv1(x))
        y = self.conv2(y)
        return F.relu(x+y)

# %%
class Net(torch.nn.Module):
    # Net类的初始化函数
    def __init__(self):
        # 继承父类的初始化函数
        super(Net, self).__init__()
        # 网络的隐藏层创建，名称可以随便起
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=3, kernel_size=10, stride=2)
        self.bn1 = nn.BatchNorm2d(3)
        self.conv2 = nn.Conv2d(in_channels=3, out_channels=6, kernel_size=10, stride=2,padding=1)
        self.bn2 = nn.BatchNorm2d(6)
        self.conv3 = nn.Conv2d(in_channels=6, out_channels=12, kernel_size=5, stride=1)
        self.bn3 = nn.BatchNorm2d(12)
        #residual
        self.rblock1 = ResidualBlock(12)
        self.conv4 = nn.Conv2d(in_channels=12, out_channels=24, kernel_size=3, stride=1)
        self.bn4 = nn.BatchNorm2d(24)
        self.rblock2 = ResidualBlock(24)
        self.conv5 = nn.Conv2d(in_channels=24, out_channels=48, kernel_size=2, stride=1)
        self.bn5 = nn.BatchNorm2d(48)
        self.rblock3 = ResidualBlock(48)
        self.conv6 = nn.Conv2d(in_channels=48, out_channels=96, kernel_size=2, stride=1)
        self.bn6 = nn.BatchNorm2d(96)
        self.pool = nn.MaxPool2d(2,2)
        self.fc1 = nn.Linear(96*8*8, 3072)
        self.fc2 = nn.Linear(3072,500)
        self.fc3 = torch.nn.Linear(500, 100)
        # 输出层(预测层)创建，接收来自隐含层的数据
        self.predict_layer = torch.nn.Linear(100, 1)

    # 网络的前向传播函数，构造计算图
    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))     #(2400-10)/2+1=1196
        x = self.pool(x)                        #1196/2=598
        x = F.relu(self.bn2(self.conv2(x)))     #(598+2-10)/2+1=296
        x = self.pool(x)                        #296/2=148
        x = F.relu(self.bn3(self.conv3(x)))     #(148-5)/1+1=144
        x = self.pool(x)                        #144/2=72
        x = self.rblock1(x)
        x = F.relu(self.bn4(self.conv4(x)))     #(72-3)/1+1=70
        x = self.pool(x)                        #70/2=35
        x = self.rblock2(x)
        x = F.relu(self.bn5(self.conv5(x)))     #(35-2)/1+1=34
        x = self.pool(x)                        #34/2=17
        x = self.rblock3(x)
        x = F.relu(self.bn6(self.conv6(x)))     #17-2+1=16
        x = self.pool(x)                        #16/2=8
        x = x.view(-1, 96*8*8)
        # 用relu函数处理隐含层输出的结果并传给输出层
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        predict_result = self.predict_layer(x)
        return predict_result

# %%
def testAccuracy():
    
    net.eval()
    accuracy = 0.0
    total = 0.0
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    #device = torch.device("cpu")

    with torch.no_grad():
        for data in valid_loader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            # run the model on the test set to predict labels
            outputs = net(images)
            # the label with the highest energy will be our prediction
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            accuracy += (predicted == labels).sum().item()
    
    # compute the accuracy over all test images
    accuracy = (100 * accuracy / total)
    return(accuracy)

def train(num_epochs):
    
    best_accuracy = 0.0

    # Define your execution device
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    #device = torch.device("cpu")

    predata=[]
    labeldata=[]
    mseloss=[]
    trainnum=[]
    # Convert model parameters and buffers to CPU or Cuda
    net.to(device)
    for epoch in range(num_epochs):  # loop over the dataset multiple times
        running_loss = 0.0
        running_acc = 0.0

        for i, (images, labels) in enumerate(train_loader, 0):
            #images, labels = dataiter.next()
            # 输入数据进行预测
            # get the inputs
            images = Variable(images.to(device))
            labels = Variable(labels.to(device))
            prediction = net(images)
            #print(prediction,labels)
            print('Prediction data is:',prediction.data.cpu().numpy()[0])
            print('label data is: ',labels.data.cpu().numpy())
            # 计算预测值与真值误差，注意参数顺序问题
            # 第一个参数为预测值，第二个为真值
            loss = loss_func(prediction, labels)

            # 开始优化步骤
            # 每次开始优化前将梯度置为0
            optimizer.zero_grad()
            # 误差反向传播
            loss.backward()
            # 按照最小loss优化参数
            optimizer.step()
            print('epoch:',i*epoch,'loss:',loss.item())
            mseloss.append(loss.data.cpu().numpy())
            trainnum.append(i*epoch)
            
            running_loss += loss.item()
            if i % 100 == 99:    
                # print every 1000 (twice per epoch) 
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 100))
                # zero the loss
                running_loss = 0.0
            predata.append(prediction.data.cpu().numpy()[0])
            labeldata.append(labels.data.cpu().numpy()[0])

            #if i % 2 == 0:
            # plot and show learning process
            #     plt.cla()
            #     # 无误差真值曲线
            #     plt.plot(labels.cpu().numpy(), labels.cpu().numpy(), c='blue', lw='3')
            #     # 实时预测的曲线
            #     plt.scatter(labels.data.cpu().numpy()[0], prediction.data.cpu().numpy()[0])
            #     plt.text(0.5, 0, 'Loss=%.4f' % loss.data.cpu().numpy(), fontdict={'size': 20, 'color':  'red'})
            #     plt.pause(0.1)
        # # 计算准确率
        # # Compute and print the average accuracy fo this epoch when tested over all 10000 test images
        
        accuracy = testAccuracy()
        print('For epoch', epoch+1,'the test accuracy over the whole test set is %d %%' % (accuracy))


    print('Finished Training')
    
    plt.figure()
    plt.plot()
    plt.plot(train_label0.data.numpy(), train_label0.data.numpy(), c='Red', lw='3')
    plt.scatter(predata,labeldata)
    plt.text(0.5, 0, 'Loss=%.4f' % loss.data.cpu().numpy(), fontdict={'size': 20, 'color':  'red'})

    
    plt.figure()
    plt.legend()
    plt.grid(True)
    plt.ylabel("Mean Squared Error")
    plt.xlabel("train times")
    plt.plot(trainnum,mseloss)

# %%
Vdataiter=iter(valid_loader)
vimg, vlabels = Vdataiter.next()
print(vimg.shape)
print(vlabels.shape)
print(vlabels)
# Out:
# torch.Size([5, 1, 2400, 2400])
# torch.Size([5, 1])
# tensor([[140.0000],
#         [109.0000],
#         [ 32.0000],
#         [ 31.5000],
#         [ 76.0000]])

# %% [markdown]
# ## 预测结果

# %%
def predict(model, device):
    Vdataiter=iter(valid_loader)
    vimg, vlabels = Vdataiter.next()
    model.to(device)
    with torch.no_grad():
        vimg=vimg.to(device)
        out = model(vimg)
        #_, pre = torch.max(out.data, 1)
        return out, vlabels

# %% [markdown]
# # 定义模型

# %%
# 输入输出的数据维度，这里都是1维
INPUT_FEATURE_DIM = 5000
# 隐含层中神经元的个数
#NEURON_NUM = 500
#OUTPUT_FEATURE_DIM = 1
# 学习率，越大学的越快，但也容易造成不稳定，准确率上下波动的情况
LEARNING_RATE = 0.001

# 定义模型
net = Net()
print(net)
# 训练网络
# 这里也可以使用其它的优化方法
optimizer = torch.optim.Adam(net.parameters(), lr=LEARNING_RATE)
# 定义一个误差计算方法
loss_func = torch.nn.MSELoss() # 定义交叉熵损失函数 交叉熵损失函数是用来衡量两个概率分布之间的距离的#nn.MSELoss()
# Define the loss function with Classification Cross-Entropy loss and an optimizer with Adam optimizer
# Out:
# Net(
#   (conv1): Conv2d(1, 3, kernel_size=(10, 10), stride=(2, 2))
#   (bn1): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(3, 6, kernel_size=(10, 10), stride=(2, 2), padding=(1, 1))
#   (bn2): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(6, 12, kernel_size=(5, 5), stride=(1, 1))
#   (bn3): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (rblock1): ResidualBlock(
#     (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv4): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1))
#   (bn4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (rblock2): ResidualBlock(
#     (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv5): Conv2d(24, 48, kernel_size=(2, 2), stride=(1, 1))
#   (bn5): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (rblock3): ResidualBlock(
#     (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conv6): Conv2d(48, 96, kernel_size=(2, 2), stride=(1, 1))
#   (bn6): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=6144, out_features=3072, bias=True)
#   (fc2): Linear(in_features=3072, out_features=500, bias=True)
#   (fc3): Linear(in_features=500, out_features=100, bias=True)
#   (predict_layer): Linear(in_features=100, out_features=1, bias=True)
# )

# %% [markdown]
# # 主函数

# %%
# Vdataiter=iter(valid_loader)
# vimg, vlabels = Vdataiter.next()
# print(vimg.shape)
# print(vlabels.shape)
# print(vlabels)
if __name__ == "__main__":

    torch.cuda.empty_cache()
    
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    #device = torch.device("cpu")
    # Let's build our model
    train(30)
    print('Finished Training')

    # Test which classes performed well
    testAccuracy()
    
    # Let's load the model we just created and test the accuracy per label
    # model = net()
    # path = "myFirstModel.pth"
    # model.load_state_dict(torch.load(path))

    print(predict(net, device))
# Out:
# Prediction data is: [0.04900451]
# label data is:  [[ 65.]
#  [154.]
#  [108.]
#  [ 37.]
#  [ 26.]]
# epoch: 0 loss: 8324.6259765625
# Prediction data is: [7.3298626]
# label data is:  [[146. ]
#  [178. ]
#  [165.5]
#  [137.5]
#  [166. ]]
# epoch: 0 loss: 23149.998046875
# Prediction data is: [29.619879]
# label data is:  [[175.]
#  [ 84.]
#  [ 76.]
#  [107.]
#  [ 81.]]
# epoch: 0 loss: 7003.28125
# Prediction data is: [72.51132]
# label data is:  [[ 39. ]
#  [ 42. ]
#  [ 41.5]
#  [105.5]
#  [ 42. ]]
# epoch: 0 loss: 950.6410522460938
# Prediction data is: [96.692566]
# label data is:  [[154.]
#  [ 43.]
#  [  8.]
#  [146.]
#  [143.]]
# epoch: 0 loss: 3487.961669921875
# Prediction data is: [128.879]
# label data is:  [[ 24.5]
#  [ 72. ]
#  [ 92. ]
#  [164. ]
#  [ 80.5]]
# epoch: 0 loss: 3465.847412109375
# Prediction data is: [103.83796]
# label data is:  [[ 28. ]
#  [165. ]
#  [ 74. ]
#  [ 81. ]
#  [ 97.5]]
# epoch: 0 loss: 2097.09375
# Prediction data is: [77.644356]
# label data is:  [[146. ]
#  [105. ]
#  [116.5]
#  [107. ]
#  [115. ]]
# epoch: 0 loss: 1907.2066650390625
# Prediction data is: [80.42418]
# label data is:  [[ 97. ]
#  [ 82. ]
#  [140. ]
#  [140.5]
#  [100. ]]
# epoch: 0 loss: 1421.5115966796875
# Prediction data is: [99.01098]
# label data is:  [[ 91.]
#  [ 64.]
#  [135.]
#  [ 33.]
#  [155.]]
# epoch: 0 loss: 2031.0911865234375
# Prediction data is: [107.78196]
# label data is:  [[35.]
#  [59.]
#  [99.]
#  [45.]
#  [47.]]
# epoch: 0 loss: 3775.97900390625
# Prediction data is: [99.808]
# label data is:  [[133. ]
#  [ 40. ]
#  [ 45.5]
#  [ 47.5]
#  [ 90. ]]
# epoch: 0 loss: 1896.9447021484375
# Prediction data is: [76.84671]
# label data is:  [[ 66.]
#  [ 74.]
#  [ 95.]
#  [150.]
#  [116.]]
# epoch: 0 loss: 1353.2464599609375
# Prediction data is: [67.49536]
# label data is:  [[ 95.5]
#  [ 50. ]
#  [ 44. ]
#  [113.5]
#  [126. ]]
# epoch: 0 loss: 1413.5364990234375
# Prediction data is: [67.151405]
# label data is:  [[127. ]
#  [ 55. ]
#  [170. ]
#  [ 29.5]
#  [ 85. ]]
# epoch: 0 loss: 3248.322998046875
# Prediction data is: [60.18712]
# label data is:  [[51. ]
#  [52. ]
#  [61. ]
#  [45.5]
#  [58. ]]
# epoch: 0 loss: 166.07839965820312
# Prediction data is: [66.24246]
# label data is:  [[150.5]
#  [ 48. ]
#  [ 34. ]
#  [ 27. ]
#  [122. ]]
# epoch: 0 loss: 2468.598388671875
# Prediction data is: [66.80109]
# label data is:  [[ 63. ]
#  [124. ]
#  [ 61. ]
#  [ 30. ]
#  [ 59.5]]
# epoch: 0 loss: 846.5145874023438
# Prediction data is: [63.656246]
# label data is:  [[ 68.]
#  [140.]
#  [118.]
#  [ 68.]
#  [ 77.]]
# epoch: 0 loss: 1256.959228515625
# Prediction data is: [82.47599]
# label data is:  [[ 59.]
#  [ 75.]
#  [ 96.]
#  [160.]
#  [161.]]
# epoch: 0 loss: 2562.936279296875
# Prediction data is: [101.43196]
# label data is:  [[130. ]
#  [158. ]
#  [124. ]
#  [ 38. ]
#  [ 20.5]]
# epoch: 0 loss: 2579.854248046875
# Prediction data is: [99.56156]
# label data is:  [[ 35.5]
#  [ 92. ]
#  [172.5]
#  [120. ]
#  [ 86. ]]
# epoch: 0 loss: 1675.157470703125
# Prediction data is: [121.15772]
# label data is:  [[ 83. ]
#  [ 22.5]
#  [ 81.5]
#  [ 72. ]
#  [150. ]]
# epoch: 0 loss: 2727.611083984375
# Prediction data is: [113.95844]
# label data is:  [[ 78.]
#  [ 20.]
#  [132.]
#  [ 37.]
#  [ 88.]]
# epoch: 0 loss: 2765.715576171875
# Prediction data is: [91.98911]
# label data is:  [[108.]
#  [ 29.]
#  [ 36.]
#  [ 25.]
#  [ 94.]]
# epoch: 0 loss: 2242.18212890625
# Prediction data is: [79.65052]
# label data is:  [[119. ]
#  [129. ]
#  [ 40.5]
#  [138. ]
#  [133. ]]
# epoch: 0 loss: 2659.66064453125
# Prediction data is: [63.15597]
# label data is:  [[ 49.5]
#  [102. ]
#  [ 56.5]
#  [144.5]
#  [ 56.5]]
# epoch: 0 loss: 1332.913330078125
# Prediction data is: [58.273567]
# label data is:  [[ 67.]
#  [111.]
#  [ 54.]
#  [110.]
#  [ 86.]]
# epoch: 0 loss: 995.9484252929688
# Prediction data is: [61.564793]
# label data is:  [[ 49.5]
#  [ 28. ]
#  [ 72. ]
#  [135. ]
#  [124. ]]
# epoch: 0 loss: 1936.576416015625
# Prediction data is: [60.929165]
# label data is:  [[ 52.]
#  [ 90.]
#  [103.]
#  [ 26.]
#  [  0.]]
# epoch: 0 loss: 1039.5618896484375
# Prediction data is: [68.91262]
# label data is:  [[ 79.]
#  [ 62.]
#  [111.]
#  [ 96.]]
# epoch: 0 loss: 796.9887084960938
# For epoch 1 the test accuracy over the whole test set is 0 %
# Prediction data is: [16.58521]
# label data is:  [[ 49.5]
#  [105. ]
#  [ 62. ]
#  [137.5]
#  [ 86. ]]
# epoch: 0 loss: 6089.1611328125
# Prediction data is: [41.55411]
# label data is:  [[165. ]
#  [ 45. ]
#  [ 88. ]
#  [ 20.5]
#  [ 52. ]]
# epoch: 1 loss: 3687.356201171875
# Prediction data is: [129.4059]
# label data is:  [[170. ]
#  [ 55. ]
#  [ 63. ]
#  [113.5]
#  [ 47. ]]
# epoch: 2 loss: 3230.40966796875
# Prediction data is: [85.54632]
# label data is:  [[124.]
#  [122.]
#  [ 61.]
#  [160.]
#  [ 67.]]
# epoch: 3 loss: 1794.826171875
# Prediction data is: [90.77444]
# label data is:  [[127. ]
#  [135. ]
#  [107. ]
#  [ 29. ]
#  [116.5]]
# epoch: 4 loss: 1600.0062255859375
# Prediction data is: [114.42962]
# label data is:  [[146. ]
#  [ 29.5]
#  [ 47.5]
#  [ 65. ]
#  [132. ]]
# epoch: 5 loss: 2715.780517578125
# Prediction data is: [103.06373]
# label data is:  [[26. ]
#  [36. ]
#  [35.5]
#  [39. ]
#  [72. ]]
# epoch: 6 loss: 3414.14111328125
# Prediction data is: [62.85954]
# label data is:  [[ 95.5]
#  [146. ]
#  [ 42. ]
#  [ 91. ]
#  [ 37. ]]
# epoch: 7 loss: 1866.1082763671875
# Prediction data is: [44.680325]
# label data is:  [[97. ]
#  [28. ]
#  [28. ]
#  [56.5]
#  [81. ]]
# epoch: 8 loss: 897.78759765625
# Prediction data is: [39.455956]
# label data is:  [[ 45.5]
#  [124. ]
#  [ 37. ]
#  [  0. ]
#  [  8. ]]
# epoch: 9 loss: 1856.3330078125
# Prediction data is: [34.913345]
# label data is:  [[107. ]
#  [ 56.5]
#  [130. ]
#  [ 99. ]
#  [ 22.5]]
# epoch: 10 loss: 3807.41455078125
# Prediction data is: [35.60172]
# label data is:  [[135.]
#  [ 75.]
#  [155.]
#  [ 30.]
#  [154.]]
# epoch: 11 loss: 7897.15478515625
# Prediction data is: [42.565426]
# label data is:  [[ 79. ]
#  [140. ]
#  [144.5]
#  [ 61. ]
#  [175. ]]
# epoch: 12 loss: 7662.7431640625
# Prediction data is: [59.388775]
# label data is:  [[40. ]
#  [49.5]
#  [92. ]
#  [82. ]
#  [40.5]]
# epoch: 13 loss: 464.23419189453125
# Prediction data is: [68.930786]
# label data is:  [[20.]
#  [26.]
#  [95.]
#  [35.]
#  [34.]]
# epoch: 14 loss: 1680.7659912109375
# Prediction data is: [91.46475]
# label data is:  [[172.5]
#  [150.5]
#  [164. ]
#  [115. ]
#  [165.5]]
# epoch: 15 loss: 4542.62939453125
# Prediction data is: [115.12966]
# label data is:  [[ 50.]
#  [ 78.]
#  [119.]
#  [154.]
#  [146.]]
# epoch: 16 loss: 1607.8638916015625
# Prediction data is: [145.13327]
# label data is:  [[ 42.]
#  [ 33.]
#  [110.]
#  [111.]
#  [126.]]
# epoch: 17 loss: 5324.83544921875
# Prediction data is: [134.27939]
# label data is:  [[59.]
#  [81.]
#  [77.]
#  [74.]
#  [84.]]
# epoch: 18 loss: 3404.411376953125
# Prediction data is: [102.77695]
# label data is:  [[150. ]
#  [ 90. ]
#  [ 24.5]
#  [ 48. ]
#  [ 51. ]]
# epoch: 19 loss: 2366.550537109375
# Prediction data is: [75.23357]
# label data is:  [[64. ]
#  [43. ]
#  [80.5]
#  [41.5]
#  [59.5]]
# epoch: 20 loss: 483.30548095703125
# Prediction data is: [55.499638]
# label data is:  [[133.]
#  [102.]
#  [ 27.]
#  [124.]
#  [ 38.]]
# epoch: 21 loss: 2894.638671875
# Prediction data is: [43.39491]
# label data is:  [[100.]
#  [161.]
#  [ 96.]
#  [ 68.]
#  [ 83.]]
# epoch: 22 loss: 4437.40869140625
# Prediction data is: [39.446907]
# label data is:  [[ 86.]
#  [118.]
#  [133.]
#  [ 96.]
#  [120.]]
# epoch: 23 loss: 5520.16015625
# Prediction data is: [39.328247]
# label data is:  [[ 54. ]
#  [ 52. ]
#  [138. ]
#  [105.5]
#  [140. ]]
# epoch: 24 loss: 4922.173828125
# Prediction data is: [43.086864]
# label data is:  [[129.]
#  [111.]
#  [ 25.]
#  [ 59.]
#  [158.]]
# epoch: 25 loss: 5248.21435546875
# Prediction data is: [49.147964]
# label data is:  [[ 97.5]
#  [ 92. ]
#  [140.5]
#  [ 90. ]
#  [ 44. ]]
# epoch: 26 loss: 2848.282470703125
# Prediction data is: [59.67265]
# label data is:  [[ 68.]
#  [166.]
#  [116.]
#  [108.]
#  [103.]]
# epoch: 27 loss: 3821.61328125
# Prediction data is: [73.94891]
# label data is:  [[143. ]
#  [ 81.5]
#  [ 94. ]
#  [ 72. ]
#  [150. ]]
# epoch: 28 loss: 2103.719482421875
# Prediction data is: [97.005035]
# label data is:  [[ 66.]
#  [108.]
#  [ 76.]
#  [178.]
#  [ 74.]]
# epoch: 29 loss: 1559.1580810546875
# Prediction data is: [117.74534]
# label data is:  [[58. ]
#  [45.5]
#  [85. ]
#  [72. ]]
# epoch: 30 loss: 3057.811767578125
# For epoch 2 the test accuracy over the whole test set is 0 %
# Prediction data is: [135.95122]
# label data is:  [[144.5]
#  [124. ]
#  [122. ]
#  [146. ]
#  [ 20. ]]
# epoch: 0 loss: 1755.904296875
# Prediction data is: [132.03868]
# label data is:  [[ 90.]
#  [135.]
#  [ 83.]
#  [116.]
#  [ 66.]]
# epoch: 2 loss: 1786.48828125
# Prediction data is: [112.245445]
# label data is:  [[ 62. ]
#  [ 29.5]
#  [158. ]
#  [126. ]
#  [ 61. ]]
# epoch: 4 loss: 3005.010498046875
# Prediction data is: [104.903824]
# label data is:  [[ 26. ]
#  [ 24.5]
#  [ 82. ]
#  [108. ]
#  [166. ]]
# epoch: 6 loss: 3426.608642578125
# Prediction data is: [88.63826]
# label data is:  [[ 36. ]
#  [ 81.5]
#  [175. ]
#  [ 39. ]
#  [ 65. ]]
# epoch: 8 loss: 2356.241943359375
# Prediction data is: [77.75413]
# label data is:  [[ 61. ]
#  [172.5]
#  [ 28. ]
#  [ 96. ]
#  [ 47. ]]
# epoch: 10 loss: 2438.800048828125
# Prediction data is: [67.57028]
# label data is:  [[108. ]
#  [ 92. ]
#  [113.5]
#  [ 47.5]
#  [ 52. ]]
# epoch: 12 loss: 956.6748046875
# Prediction data is: [59.272804]
# label data is:  [[140. ]
#  [150.5]
#  [ 97.5]
#  [ 44. ]
#  [ 50. ]]
# epoch: 14 loss: 3253.470703125
# Prediction data is: [57.961403]
# label data is:  [[ 64. ]
#  [110. ]
#  [ 95.5]
#  [115. ]
#  [ 68. ]]
# epoch: 16 loss: 1492.3612060546875
# Prediction data is: [52.059353]
# label data is:  [[ 35.]
#  [ 91.]
#  [ 74.]
#  [164.]
#  [ 33.]]
# epoch: 18 loss: 2659.8935546875
# Prediction data is: [59.63041]
# label data is:  [[ 74.]
#  [124.]
#  [143.]
#  [155.]
#  [ 77.]]
# epoch: 20 loss: 3927.038330078125
# Prediction data is: [66.84228]
# label data is:  [[ 79.]
#  [133.]
#  [ 92.]
#  [ 75.]
#  [ 84.]]
# epoch: 22 loss: 1119.93408203125
# Prediction data is: [67.52005]
# label data is:  [[48. ]
#  [20.5]
#  [49.5]
#  [81. ]
#  [ 8. ]]
# epoch: 24 loss: 1857.5074462890625
# Prediction data is: [82.50091]
# label data is:  [[140.5]
#  [178. ]
#  [107. ]
#  [ 30. ]
#  [ 28. ]]
# epoch: 26 loss: 3352.01611328125
# Prediction data is: [88.8402]
# label data is:  [[ 49.5]
#  [105.5]
#  [ 40.5]
#  [ 94. ]
#  [ 51. ]]
# epoch: 28 loss: 958.5922241210938
# Prediction data is: [99.80452]
# label data is:  [[165.]
#  [150.]
#  [111.]
#  [107.]
#  [ 42.]]
# epoch: 30 loss: 2059.142333984375
# Prediction data is: [100.562614]
# label data is:  [[ 45.5]
#  [ 22.5]
#  [ 56.5]
#  [161. ]
#  [ 86. ]]
# epoch: 32 loss: 3104.471435546875
# Prediction data is: [101.61735]
# label data is:  [[ 72. ]
#  [102. ]
#  [150. ]
#  [ 80.5]
#  [ 25. ]]
# epoch: 34 loss: 1703.078125
# Prediction data is: [95.53599]
# label data is:  [[ 41.5]
#  [160. ]
#  [146. ]
#  [ 72. ]
#  [ 26. ]]
# epoch: 36 loss: 2845.174560546875
# Prediction data is: [85.879295]
# label data is:  [[ 97.]
#  [ 90.]
#  [ 78.]
#  [105.]
#  [ 42.]]
# epoch: 38 loss: 430.17462158203125
# Prediction data is: [91.73965]
# label data is:  [[ 43. ]
#  [116.5]
#  [ 88. ]
#  [ 27. ]
#  [ 52. ]]
# epoch: 40 loss: 1581.9136962890625
# Prediction data is: [83.857285]
# label data is:  [[34. ]
#  [35.5]
#  [56.5]
#  [55. ]
#  [95. ]]
# epoch: 42 loss: 1174.269287109375
# Prediction data is: [72.978874]
# label data is:  [[ 81.]
#  [132.]
#  [ 37.]
#  [140.]
#  [120.]]
# epoch: 44 loss: 2114.058349609375
# Prediction data is: [71.532036]
# label data is:  [[127. ]
#  [ 86. ]
#  [129. ]
#  [ 59. ]
#  [137.5]]
# epoch: 46 loss: 2258.549560546875
# Prediction data is: [70.26537]
# label data is:  [[103.]
#  [111.]
#  [ 76.]
#  [ 38.]
#  [ 72.]]
# epoch: 48 loss: 691.8528442382812
# Prediction data is: [70.940506]
# label data is:  [[ 68. ]
#  [ 63. ]
#  [ 45. ]
#  [ 59.5]
#  [165.5]]
# epoch: 50 loss: 1690.5361328125
# Prediction data is: [71.930984]
# label data is:  [[ 99. ]
#  [170. ]
#  [ 45.5]
#  [ 58. ]
#  [ 59. ]]
# epoch: 52 loss: 2108.490234375
# Prediction data is: [79.986855]
# label data is:  [[119.]
#  [ 85.]
#  [133.]
#  [130.]
#  [ 96.]]
# epoch: 54 loss: 1567.9283447265625
# Prediction data is: [85.19841]
# label data is:  [[146.]
#  [  0.]
#  [ 40.]
#  [ 54.]
#  [118.]]
# epoch: 56 loss: 2689.618896484375
# Prediction data is: [95.34349]
# label data is:  [[154.]
#  [ 37.]
#  [124.]
#  [100.]
#  [154.]]
# epoch: 58 loss: 2383.13671875
# Prediction data is: [95.17612]
# label data is:  [[135.]
#  [ 29.]
#  [138.]
#  [ 67.]]
# epoch: 60 loss: 2169.140625
# For epoch 3 the test accuracy over the whole test set is 0 %
# Prediction data is: [111.094574]
# label data is:  [[143.]
#  [115.]
#  [155.]
#  [140.]
#  [ 78.]]
# epoch: 0 loss: 908.5029296875
# Prediction data is: [117.174446]
# label data is:  [[146.]
#  [129.]
#  [133.]
#  [ 92.]
#  [111.]]
# epoch: 3 loss: 449.74151611328125
# Prediction data is: [133.17505]
# label data is:  [[133. ]
#  [ 24.5]
#  [ 34. ]
#  [ 48. ]
#  [103. ]]
# epoch: 6 loss: 5437.95068359375
# Prediction data is: [136.10216]
# label data is:  [[150. ]
#  [ 61. ]
#  [158. ]
#  [165.5]
#  [ 80.5]]
# epoch: 9 loss: 1394.165283203125
# Prediction data is: [118.36344]
# label data is:  [[ 64. ]
#  [ 47.5]
#  [100. ]
#  [150.5]
#  [ 20. ]]
# epoch: 12 loss: 2668.7412109375
# Prediction data is: [104.57107]
# label data is:  [[ 49.5]
#  [ 55. ]
#  [ 47. ]
#  [113.5]
#  [ 40.5]]
# epoch: 15 loss: 2274.73046875
# Prediction data is: [81.71112]
# label data is:  [[ 95.5]
#  [166. ]
#  [ 63. ]
#  [ 28. ]
#  [135. ]]
# epoch: 18 loss: 2240.05078125
# Prediction data is: [75.33697]
# label data is:  [[122.]
#  [164.]
#  [ 52.]
#  [ 96.]
#  [ 90.]]
# epoch: 21 loss: 2328.876708984375
# Prediction data is: [67.32357]
# label data is:  [[22.5]
#  [35.5]
#  [81. ]
#  [72. ]
#  [92. ]]
# epoch: 24 loss: 724.9410400390625
# Prediction data is: [59.64502]
# label data is:  [[ 52. ]
#  [ 96. ]
#  [ 38. ]
#  [161. ]
#  [ 29.5]]
# epoch: 27 loss: 2403.123779296875
# Prediction data is: [59.832054]
# label data is:  [[ 83.]
#  [146.]
#  [ 82.]
#  [ 97.]
#  [ 36.]]
# epoch: 30 loss: 2128.77099609375
# Prediction data is: [56.98048]
# label data is:  [[ 77.]
#  [110.]
#  [  0.]
#  [111.]
#  [138.]]
# epoch: 33 loss: 2987.344482421875
# Prediction data is: [62.44176]
# label data is:  [[124. ]
#  [127. ]
#  [160. ]
#  [ 81.5]
#  [ 27. ]]
# epoch: 36 loss: 3563.346923828125
# Prediction data is: [60.155975]
# label data is:  [[105.]
#  [ 50.]
#  [ 79.]
#  [ 40.]
#  [ 76.]]
# epoch: 39 loss: 635.317138671875
# Prediction data is: [71.61293]
# label data is:  [[130.]
#  [ 37.]
#  [140.]
#  [ 30.]
#  [146.]]
# epoch: 42 loss: 3062.02880859375
# Prediction data is: [83.45354]
# label data is:  [[26. ]
#  [62. ]
#  [90. ]
#  [66. ]
#  [49.5]]
# epoch: 45 loss: 876.46826171875
# Prediction data is: [87.61522]
# label data is:  [[ 74. ]
#  [172.5]
#  [ 91. ]
#  [ 44. ]
#  [ 97.5]]
# epoch: 48 loss: 1444.696533203125
# Prediction data is: [88.20154]
# label data is:  [[ 45.5]
#  [ 41.5]
#  [126. ]
#  [108. ]
#  [ 20.5]]
# epoch: 51 loss: 2143.142333984375
# Prediction data is: [73.265976]
# label data is:  [[ 51. ]
#  [ 37. ]
#  [154. ]
#  [144.5]
#  [ 72. ]]
# epoch: 54 loss: 2108.034912109375
# Prediction data is: [94.26546]
# label data is:  [[ 59. ]
#  [ 25. ]
#  [ 88. ]
#  [137.5]
#  [ 65. ]]
# epoch: 57 loss: 1512.8558349609375
# Prediction data is: [102.63094]
# label data is:  [[150.]
#  [107.]
#  [ 42.]
#  [ 29.]
#  [ 43.]]
# epoch: 60 loss: 2443.993408203125
# Prediction data is: [87.26964]
# label data is:  [[ 56.5]
#  [ 35. ]
#  [124. ]
#  [ 86. ]
#  [108. ]]
# epoch: 63 loss: 864.5074462890625
# Prediction data is: [71.208984]
# label data is:  [[81.]
#  [85.]
#  [28.]
#  [59.]
#  [67.]]
# epoch: 66 loss: 1086.8726806640625
# Prediction data is: [88.21393]
# label data is:  [[170. ]
#  [ 39. ]
#  [116.5]
#  [ 68. ]
#  [120. ]]
# epoch: 69 loss: 1976.940673828125
# Prediction data is: [62.204746]
# label data is:  [[ 75.]
#  [175.]
#  [ 54.]
#  [116.]
#  [ 72.]]
# epoch: 72 loss: 1907.6939697265625
# Prediction data is: [82.54671]
# label data is:  [[ 61.]
#  [107.]
#  [135.]
#  [ 84.]
#  [165.]]
# epoch: 75 loss: 1900.2484130859375
# Prediction data is: [78.423965]
# label data is:  [[ 99. ]
#  [  8. ]
#  [140.5]
#  [ 68. ]
#  [ 86. ]]
# epoch: 78 loss: 1868.8309326171875
# Prediction data is: [92.83506]
# label data is:  [[ 95. ]
#  [ 74. ]
#  [ 33. ]
#  [124. ]
#  [ 45.5]]
# epoch: 81 loss: 897.173828125
# Prediction data is: [98.80188]
# label data is:  [[119. ]
#  [ 56.5]
#  [102. ]
#  [154. ]
#  [105.5]]
# epoch: 84 loss: 1072.216796875
# Prediction data is: [102.39374]
# label data is:  [[45.]
#  [58.]
#  [94.]
#  [26.]
#  [42.]]
# epoch: 87 loss: 1620.3123779296875
# Prediction data is: [75.62409]
# label data is:  [[118. ]
#  [132. ]
#  [ 59.5]
#  [178. ]]
# epoch: 90 loss: 1991.35205078125
# For epoch 4 the test accuracy over the whole test set is 0 %
# Prediction data is: [94.18475]
# label data is:  [[132. ]
#  [ 29.5]
#  [ 27. ]
#  [ 83. ]
#  [ 56.5]]
# epoch: 0 loss: 2141.61328125
# Prediction data is: [96.114914]
# label data is:  [[ 22.5]
#  [150. ]
#  [170. ]
#  [102. ]
#  [116.5]]
# epoch: 4 loss: 2378.393798828125
# Prediction data is: [126.087456]
# label data is:  [[172.5]
#  [ 24.5]
#  [ 45.5]
#  [ 40.5]
#  [ 59. ]]
# epoch: 8 loss: 2624.447998046875
# Prediction data is: [80.40185]
# label data is:  [[33.]
#  [40.]
#  [64.]
#  [63.]
#  [86.]]
# epoch: 12 loss: 1343.210693359375
# Prediction data is: [72.74323]
# label data is:  [[ 52. ]
#  [150.5]
#  [ 72. ]
#  [ 94. ]
#  [111. ]]
# epoch: 16 loss: 983.3638916015625
# Prediction data is: [86.69043]
# label data is:  [[122.]
#  [ 79.]
#  [ 82.]
#  [ 81.]
#  [ 26.]]
# epoch: 20 loss: 869.3173217773438
# Prediction data is: [66.57249]
# label data is:  [[ 74.]
#  [175.]
#  [ 54.]
#  [115.]
#  [ 59.]]
# epoch: 24 loss: 1964.7060546875
# Prediction data is: [60.71958]
# label data is:  [[ 29.]
#  [118.]
#  [127.]
#  [108.]
#  [ 42.]]
# epoch: 28 loss: 1662.5865478515625
# Prediction data is: [37.7206]
# label data is:  [[  0. ]
#  [ 61. ]
#  [ 47.5]
#  [ 66. ]
#  [164. ]]
# epoch: 32 loss: 1711.0269775390625
# Prediction data is: [76.986176]
# label data is:  [[78.]
#  [90.]
#  [75.]
#  [65.]
#  [84.]]
# epoch: 36 loss: 141.79751586914062
# Prediction data is: [68.98649]
# label data is:  [[ 36. ]
#  [ 49.5]
#  [ 62. ]
#  [ 35.5]
#  [146. ]]
# epoch: 40 loss: 1696.958984375
# Prediction data is: [74.0717]
# label data is:  [[ 88. ]
#  [ 42. ]
#  [ 97. ]
#  [ 49.5]
#  [140. ]]
# epoch: 44 loss: 1927.8577880859375
# Prediction data is: [78.83649]
# label data is:  [[ 91.]
#  [ 95.]
#  [107.]
#  [ 45.]
#  [124.]]
# epoch: 48 loss: 1020.1209106445312
# Prediction data is: [79.22317]
# label data is:  [[154.]
#  [119.]
#  [ 39.]
#  [107.]
#  [108.]]
# epoch: 52 loss: 1304.80908203125
# Prediction data is: [122.42889]
# label data is:  [[166. ]
#  [ 41.5]
#  [ 96. ]
#  [143. ]
#  [ 90. ]]
# epoch: 56 loss: 1296.7122802734375
# Prediction data is: [117.35275]
# label data is:  [[161. ]
#  [ 28. ]
#  [138. ]
#  [ 61. ]
#  [ 20.5]]
# epoch: 60 loss: 2290.24365234375
# Prediction data is: [94.2437]
# label data is:  [[ 85. ]
#  [154. ]
#  [120. ]
#  [137.5]
#  [ 86. ]]
# epoch: 64 loss: 555.5098876953125
# Prediction data is: [102.055786]
# label data is:  [[ 77. ]
#  [ 26. ]
#  [165.5]
#  [ 25. ]
#  [165. ]]
# epoch: 68 loss: 2236.281982421875
# Prediction data is: [90.45405]
# label data is:  [[ 52. ]
#  [ 81.5]
#  [155. ]
#  [ 92. ]
#  [ 72. ]]
# epoch: 72 loss: 790.4444580078125
# Prediction data is: [103.62453]
# label data is:  [[43.]
#  [72.]
#  [74.]
#  [50.]
#  [81.]]
# epoch: 76 loss: 1030.6336669921875
# Prediction data is: [73.6864]
# label data is:  [[100.]
#  [135.]
#  [ 92.]
#  [  8.]
#  [124.]]
# epoch: 80 loss: 2116.919189453125
# Prediction data is: [82.82952]
# label data is:  [[146.]
#  [ 96.]
#  [129.]
#  [ 28.]
#  [130.]]
# epoch: 84 loss: 2870.06201171875
# Prediction data is: [56.178215]
# label data is:  [[ 44. ]
#  [158. ]
#  [ 47. ]
#  [110. ]
#  [144.5]]
# epoch: 88 loss: 1960.6763916015625
# Prediction data is: [63.999275]
# label data is:  [[ 80.5]
#  [ 68. ]
#  [103. ]
#  [ 45.5]
#  [146. ]]
# epoch: 92 loss: 1644.964111328125
# Prediction data is: [60.7403]
# label data is:  [[135.]
#  [ 48.]
#  [ 34.]
#  [133.]
#  [ 35.]]
# epoch: 96 loss: 1893.3687744140625
# Prediction data is: [118.604294]
# label data is:  [[150.]
#  [ 38.]
#  [ 20.]
#  [126.]
#  [160.]]
# epoch: 100 loss: 1328.7633056640625
# Prediction data is: [69.955574]
# label data is:  [[111. ]
#  [ 95.5]
#  [ 67. ]
#  [105.5]
#  [ 37. ]]
# epoch: 104 loss: 512.2642822265625
# Prediction data is: [122.730385]
# label data is:  [[ 97.5]
#  [133. ]
#  [ 99. ]
#  [105. ]
#  [116. ]]
# epoch: 108 loss: 486.7660827636719
# Prediction data is: [148.37032]
# label data is:  [[ 68. ]
#  [ 51. ]
#  [ 59.5]
#  [140.5]
#  [124. ]]
# epoch: 112 loss: 1922.7828369140625
# Prediction data is: [143.27249]
# label data is:  [[140. ]
#  [ 58. ]
#  [ 56.5]
#  [ 55. ]
#  [178. ]]
# epoch: 116 loss: 1645.7054443359375
# Prediction data is: [130.03723]
# label data is:  [[ 76. ]
#  [ 37. ]
#  [113.5]
#  [ 30. ]]
# epoch: 120 loss: 5791.0439453125
# For epoch 5 the test accuracy over the whole test set is 0 %
# Prediction data is: [104.39215]
# label data is:  [[ 96. ]
#  [ 40.5]
#  [  8. ]
#  [119. ]
#  [ 49.5]]
# epoch: 0 loss: 1644.3336181640625
# Prediction data is: [62.547596]
# label data is:  [[65.]
#  [27.]
#  [85.]
#  [78.]
#  [79.]]
# epoch: 5 loss: 369.8299865722656
# Prediction data is: [58.44062]
# label data is:  [[ 56.5]
#  [ 42. ]
#  [146. ]
#  [124. ]
#  [ 66. ]]
# epoch: 10 loss: 2188.298095703125
# Prediction data is: [47.04349]
# label data is:  [[130. ]
#  [ 77. ]
#  [ 36. ]
#  [ 49.5]
#  [ 29. ]]
# epoch: 15 loss: 1631.1492919921875
# Prediction data is: [44.569324]
# label data is:  [[158. ]
#  [172.5]
#  [ 39. ]
#  [ 88. ]
#  [150. ]]
# epoch: 20 loss: 7907.83837890625
# Prediction data is: [40.252453]
# label data is:  [[102.]
#  [ 64.]
#  [ 44.]
#  [118.]
#  [ 34.]]
# epoch: 25 loss: 2181.5576171875
# Prediction data is: [45.903873]
# label data is:  [[170. ]
#  [ 22.5]
#  [ 81. ]
#  [ 80.5]
#  [105.5]]
# epoch: 30 loss: 4483.19287109375
# Prediction data is: [48.056114]
# label data is:  [[116.5]
#  [ 20.5]
#  [ 26. ]
#  [107. ]
#  [124. ]]
# epoch: 35 loss: 3034.88037109375
# Prediction data is: [49.29443]
# label data is:  [[ 45.5]
#  [135. ]
#  [ 96. ]
#  [ 94. ]
#  [ 37. ]]
# epoch: 40 loss: 2437.948974609375
# Prediction data is: [58.00391]
# label data is:  [[150.5]
#  [166. ]
#  [ 35. ]
#  [ 81. ]
#  [140. ]]
# epoch: 45 loss: 5587.4130859375
# Prediction data is: [69.78198]
# label data is:  [[ 92.]
#  [100.]
#  [ 61.]
#  [ 43.]
#  [  0.]]
# epoch: 50 loss: 1053.4195556640625
# Prediction data is: [77.11737]
# label data is:  [[ 74.]
#  [ 72.]
#  [ 75.]
#  [146.]
#  [165.]]
# epoch: 55 loss: 2170.975341796875
# Prediction data is: [88.81093]
# label data is:  [[ 58. ]
#  [140.5]
#  [ 59. ]
#  [ 52. ]
#  [ 86. ]]
# epoch: 60 loss: 1128.3970947265625
# Prediction data is: [104.73288]
# label data is:  [[ 72.]
#  [ 62.]
#  [ 51.]
#  [ 68.]
#  [154.]]
# epoch: 65 loss: 1465.01171875
# Prediction data is: [106.56707]
# label data is:  [[105.]
#  [ 28.]
#  [133.]
#  [ 40.]
#  [ 68.]]
# epoch: 70 loss: 3028.415771484375
# Prediction data is: [121.389084]
# label data is:  [[175.]
#  [132.]
#  [178.]
#  [ 25.]
#  [ 48.]]
# epoch: 75 loss: 2954.6171875
# Prediction data is: [110.662155]
# label data is:  [[ 52.]
#  [110.]
#  [ 59.]
#  [155.]
#  [ 91.]]
# epoch: 80 loss: 1638.2034912109375
# Prediction data is: [112.485405]
# label data is:  [[ 54. ]
#  [ 81.5]
#  [135. ]
#  [122. ]
#  [ 45.5]]
# epoch: 85 loss: 1711.744140625
# Prediction data is: [99.82548]
# label data is:  [[146.]
#  [164.]
#  [111.]
#  [108.]
#  [120.]]
# epoch: 90 loss: 1128.2203369140625
# Prediction data is: [97.43119]
# label data is:  [[ 29.5]
#  [140. ]
#  [129. ]
#  [ 47.5]
#  [ 97. ]]
# epoch: 95 loss: 1753.3779296875
# Prediction data is: [104.07987]
# label data is:  [[116.]
#  [ 45.]
#  [127.]
#  [ 47.]
#  [ 38.]]
# epoch: 100 loss: 1878.9285888671875
# Prediction data is: [93.20142]
# label data is:  [[161. ]
#  [ 82. ]
#  [111. ]
#  [ 24.5]
#  [ 67. ]]
# epoch: 105 loss: 2028.8668212890625
# Prediction data is: [88.75509]
# label data is:  [[107. ]
#  [126. ]
#  [ 97.5]
#  [138. ]
#  [ 33. ]]
# epoch: 110 loss: 1569.833251953125
# Prediction data is: [69.38201]
# label data is:  [[ 72. ]
#  [ 35.5]
#  [ 90. ]
#  [150. ]
#  [ 20. ]]
# epoch: 115 loss: 1576.8779296875
# Prediction data is: [81.28575]
# label data is:  [[ 90. ]
#  [ 30. ]
#  [137.5]
#  [ 83. ]
#  [ 63. ]]
# epoch: 120 loss: 1116.867431640625
# Prediction data is: [76.328705]
# label data is:  [[ 76.]
#  [ 55.]
#  [154.]
#  [ 99.]
#  [ 26.]]
# epoch: 125 loss: 2038.606689453125
# Prediction data is: [55.261517]
# label data is:  [[ 37.]
#  [124.]
#  [108.]
#  [ 92.]
#  [ 61.]]
# epoch: 130 loss: 1008.3615112304688
# Prediction data is: [72.76947]
# label data is:  [[133. ]
#  [ 28. ]
#  [ 41.5]
#  [103. ]
#  [113.5]]
# epoch: 135 loss: 1352.3824462890625
# Prediction data is: [77.70524]
# label data is:  [[115. ]
#  [ 56.5]
#  [144.5]
#  [ 42. ]
#  [ 59.5]]
# epoch: 140 loss: 886.86376953125
# Prediction data is: [108.5013]
# label data is:  [[165.5]
#  [143. ]
#  [ 95.5]
#  [ 84. ]
#  [ 50. ]]
# epoch: 145 loss: 1655.4990234375
# Prediction data is: [94.32751]
# label data is:  [[ 86.]
#  [ 95.]
#  [ 74.]
#  [160.]]
# epoch: 150 loss: 621.8626708984375
# For epoch 6 the test accuracy over the whole test set is 0 %
# Prediction data is: [86.68969]
# label data is:  [[ 44.]
#  [ 26.]
#  [ 92.]
#  [124.]
#  [ 58.]]
# epoch: 0 loss: 1598.2869873046875
# Prediction data is: [93.216835]
# label data is:  [[108.]
#  [ 28.]
#  [ 51.]
#  [ 35.]
#  [135.]]
# epoch: 6 loss: 994.4384765625
# Prediction data is: [111.147125]
# label data is:  [[124. ]
#  [ 56.5]
#  [  0. ]
#  [143. ]
#  [ 49.5]]
# epoch: 12 loss: 2069.998046875
# Prediction data is: [94.72208]
# label data is:  [[ 77. ]
#  [ 81.5]
#  [ 43. ]
#  [ 29.5]
#  [113.5]]
# epoch: 18 loss: 1822.144775390625
# Prediction data is: [88.63547]
# label data is:  [[ 80.5]
#  [ 95.5]
#  [146. ]
#  [132. ]
#  [ 91. ]]
# epoch: 24 loss: 1011.8175048828125
# Prediction data is: [77.31804]
# label data is:  [[105. ]
#  [ 49.5]
#  [178. ]
#  [150. ]
#  [ 40. ]]
# epoch: 30 loss: 2012.917236328125
# Prediction data is: [102.783615]
# label data is:  [[129.]
#  [ 39.]
#  [ 52.]
#  [155.]
#  [158.]]
# epoch: 36 loss: 1244.2158203125
# Prediction data is: [83.35595]
# label data is:  [[ 85.]
#  [ 76.]
#  [111.]
#  [ 37.]
#  [ 94.]]
# epoch: 42 loss: 369.2462158203125
# Prediction data is: [88.962166]
# label data is:  [[  8.]
#  [ 37.]
#  [ 90.]
#  [ 27.]
#  [124.]]
# epoch: 48 loss: 2890.0146484375
# Prediction data is: [68.53942]
# label data is:  [[118. ]
#  [ 61. ]
#  [133. ]
#  [105.5]
#  [ 90. ]]
# epoch: 54 loss: 627.2638549804688
# Prediction data is: [87.06345]
# label data is:  [[ 64. ]
#  [140.5]
#  [110. ]
#  [122. ]
#  [ 81. ]]
# epoch: 60 loss: 791.4149169921875
# Prediction data is: [105.36223]
# label data is:  [[154.]
#  [108.]
#  [ 86.]
#  [ 81.]
#  [140.]]
# epoch: 66 loss: 1593.550048828125
# Prediction data is: [89.38672]
# label data is:  [[115. ]
#  [ 59.5]
#  [ 47.5]
#  [ 65. ]
#  [ 63. ]]
# epoch: 72 loss: 392.1869201660156
# Prediction data is: [90.959236]
# label data is:  [[138.]
#  [161.]
#  [164.]
#  [ 61.]
#  [ 92.]]
# epoch: 78 loss: 1691.060546875
# Prediction data is: [138.51988]
# label data is:  [[ 68.]
#  [ 78.]
#  [ 50.]
#  [146.]
#  [ 97.]]
# epoch: 84 loss: 2187.314208984375
# Prediction data is: [139.68571]
# label data is:  [[ 82. ]
#  [170. ]
#  [165.5]
#  [ 33. ]
#  [ 68. ]]
# epoch: 90 loss: 1845.8656005859375
# Prediction data is: [114.83376]
# label data is:  [[ 34.]
#  [107.]
#  [126.]
#  [ 75.]
#  [ 74.]]
# epoch: 96 loss: 1630.2991943359375
# Prediction data is: [127.24671]
# label data is:  [[146. ]
#  [ 97.5]
#  [ 45.5]
#  [135. ]
#  [ 66. ]]
# epoch: 102 loss: 1256.5526123046875
# Prediction data is: [84.940155]
# label data is:  [[ 22.5]
#  [ 62. ]
#  [120. ]
#  [150. ]
#  [ 84. ]]
# epoch: 108 loss: 1152.6929931640625
# Prediction data is: [33.406017]
# label data is:  [[ 48. ]
#  [160. ]
#  [137.5]
#  [107. ]
#  [144.5]]
# epoch: 114 loss: 780.8002319335938
# Prediction data is: [87.137245]
# label data is:  [[ 45. ]
#  [102. ]
#  [175. ]
#  [ 56.5]
#  [ 41.5]]
# epoch: 120 loss: 1389.6424560546875
# Prediction data is: [32.41561]
# label data is:  [[20. ]
#  [24.5]
#  [72. ]
#  [88. ]
#  [25. ]]
# epoch: 126 loss: 1005.6928100585938
# Prediction data is: [68.21681]
# label data is:  [[154. ]
#  [ 40.5]
#  [116. ]
#  [111. ]
#  [ 54. ]]
# epoch: 132 loss: 1751.6474609375
# Prediction data is: [65.09378]
# label data is:  [[ 29.]
#  [166.]
#  [100.]
#  [ 72.]
#  [ 79.]]
# epoch: 138 loss: 1492.090087890625
# Prediction data is: [71.57228]
# label data is:  [[ 20.5]
#  [ 59. ]
#  [ 47. ]
#  [ 26. ]
#  [103. ]]
# epoch: 144 loss: 1378.163330078125
# Prediction data is: [64.8415]
# label data is:  [[ 52. ]
#  [116.5]
#  [ 28. ]
#  [ 45.5]
#  [ 96. ]]
# epoch: 150 loss: 924.7760009765625
# Prediction data is: [65.79862]
# label data is:  [[133. ]
#  [127. ]
#  [172.5]
#  [ 30. ]
#  [ 95. ]]
# epoch: 156 loss: 1715.7352294921875
# Prediction data is: [87.67662]
# label data is:  [[96. ]
#  [67. ]
#  [35.5]
#  [42. ]
#  [99. ]]
# epoch: 162 loss: 499.807373046875
# Prediction data is: [33.461613]
# label data is:  [[ 42. ]
#  [130. ]
#  [ 59. ]
#  [150.5]
#  [ 86. ]]
# epoch: 168 loss: 1956.673095703125
# Prediction data is: [71.93372]
# label data is:  [[ 55.]
#  [ 72.]
#  [ 83.]
#  [165.]
#  [140.]]
# epoch: 174 loss: 704.507080078125
# Prediction data is: [88.11902]
# label data is:  [[ 74.]
#  [119.]
#  [ 38.]
#  [ 36.]]
# epoch: 180 loss: 951.6956176757812
# For epoch 7 the test accuracy over the whole test set is 0 %
# Prediction data is: [77.55871]
# label data is:  [[ 42.]
#  [122.]
#  [110.]
#  [166.]
#  [100.]]
# epoch: 0 loss: 538.7988891601562
# Prediction data is: [80.86117]
# label data is:  [[154.]
#  [ 65.]
#  [ 62.]
#  [ 26.]
#  [ 27.]]
# epoch: 7 loss: 3048.5634765625
# Prediction data is: [97.178055]
# label data is:  [[ 64. ]
#  [ 20. ]
#  [ 28. ]
#  [150.5]
#  [ 39. ]]
# epoch: 14 loss: 709.3812255859375
# Prediction data is: [68.1979]
# label data is:  [[38.]
#  [30.]
#  [75.]
#  [59.]
#  [ 0.]]
# epoch: 21 loss: 1483.6461181640625
# Prediction data is: [65.34099]
# label data is:  [[ 59. ]
#  [113.5]
#  [124. ]
#  [ 83. ]
#  [105.5]]
# epoch: 28 loss: 121.84565734863281
# Prediction data is: [42.18824]
# label data is:  [[ 81.]
#  [ 61.]
#  [ 96.]
#  [ 68.]
#  [146.]]
# epoch: 35 loss: 2470.90478515625
# Prediction data is: [51.75585]
# label data is:  [[ 26. ]
#  [103. ]
#  [158. ]
#  [127. ]
#  [ 56.5]]
# epoch: 42 loss: 1863.9365234375
# Prediction data is: [52.87328]
# label data is:  [[ 52. ]
#  [ 37. ]
#  [102. ]
#  [165.5]
#  [ 33. ]]
# epoch: 49 loss: 574.927001953125
# Prediction data is: [59.63142]
# label data is:  [[ 35.5]
#  [ 22.5]
#  [ 37. ]
#  [129. ]
#  [ 84. ]]
# epoch: 56 loss: 1033.927001953125
# Prediction data is: [64.970604]
# label data is:  [[ 40. ]
#  [138. ]
#  [ 41.5]
#  [ 92. ]
#  [ 49.5]]
# epoch: 63 loss: 1646.849853515625
# Prediction data is: [63.488426]
# label data is:  [[124. ]
#  [ 45.5]
#  [ 97. ]
#  [133. ]
#  [ 28. ]]
# epoch: 70 loss: 1532.777587890625
# Prediction data is: [105.338104]
# label data is:  [[116.5]
#  [105. ]
#  [ 54. ]
#  [ 82. ]
#  [ 25. ]]
# epoch: 77 loss: 791.3522338867188
# Prediction data is: [93.2156]
# label data is:  [[ 43.]
#  [ 77.]
#  [146.]
#  [116.]
#  [ 29.]]
# epoch: 84 loss: 1902.805908203125
# Prediction data is: [75.67032]
# label data is:  [[72. ]
#  [97.5]
#  [78. ]
#  [56.5]
#  [48. ]]
# epoch: 91 loss: 133.8688201904297
# Prediction data is: [72.11105]
# label data is:  [[ 49.5]
#  [ 47.5]
#  [ 81.5]
#  [ 90. ]
#  [144.5]]
# epoch: 98 loss: 430.99102783203125
# Prediction data is: [117.90096]
# label data is:  [[146. ]
#  [ 66. ]
#  [ 72. ]
#  [ 59.5]
#  [ 74. ]]
# epoch: 105 loss: 267.8129577636719
# Prediction data is: [78.2648]
# label data is:  [[ 24.5]
#  [172.5]
#  [ 35. ]
#  [150. ]
#  [140. ]]
# epoch: 112 loss: 1415.208740234375
# Prediction data is: [135.75687]
# label data is:  [[175.]
#  [170.]
#  [ 47.]
#  [ 86.]
#  [164.]]
# epoch: 119 loss: 1896.6976318359375
# Prediction data is: [85.20171]
# label data is:  [[ 76. ]
#  [ 36. ]
#  [ 45. ]
#  [ 80.5]
#  [140. ]]
# epoch: 126 loss: 1448.334228515625
# Prediction data is: [134.9611]
# label data is:  [[119.]
#  [ 86.]
#  [130.]
#  [111.]
#  [ 92.]]
# epoch: 133 loss: 796.2598876953125
# Prediction data is: [169.16087]
# label data is:  [[160. ]
#  [140.5]
#  [ 61. ]
#  [ 95. ]
#  [ 42. ]]
# epoch: 140 loss: 753.2169799804688
# Prediction data is: [108.68764]
# label data is:  [[ 96. ]
#  [ 20.5]
#  [ 95.5]
#  [ 45.5]
#  [135. ]]
# epoch: 147 loss: 1816.8944091796875
# Prediction data is: [83.87563]
# label data is:  [[108.]
#  [ 72.]
#  [161.]
#  [107.]
#  [154.]]
# epoch: 154 loss: 1129.8143310546875
# Prediction data is: [91.53763]
# label data is:  [[115. ]
#  [137.5]
#  [133. ]
#  [ 63. ]
#  [165. ]]
# epoch: 161 loss: 835.1209106445312
# Prediction data is: [59.605686]
# label data is:  [[ 51.]
#  [ 99.]
#  [143.]
#  [107.]
#  [ 88.]]
# epoch: 168 loss: 629.0470581054688
# Prediction data is: [102.163055]
# label data is:  [[120.]
#  [111.]
#  [150.]
#  [ 67.]
#  [155.]]
# epoch: 175 loss: 516.6118774414062
# Prediction data is: [108.04008]
# label data is:  [[ 91.]
#  [ 52.]
#  [ 85.]
#  [ 94.]
#  [118.]]
# epoch: 182 loss: 1162.1077880859375
# Prediction data is: [104.86824]
# label data is:  [[ 8. ]
#  [68. ]
#  [40.5]
#  [90. ]
#  [29.5]]
# epoch: 189 loss: 4425.78857421875
# Prediction data is: [89.8335]
# label data is:  [[126.]
#  [ 44.]
#  [ 81.]
#  [124.]
#  [135.]]
# epoch: 196 loss: 948.15966796875
# Prediction data is: [72.71946]
# label data is:  [[ 55.]
#  [178.]
#  [ 50.]
#  [ 34.]
#  [ 74.]]
# epoch: 203 loss: 818.3468627929688
# Prediction data is: [86.34159]
# label data is:  [[108.]
#  [132.]
#  [ 79.]
#  [ 58.]]
# epoch: 210 loss: 1187.661865234375
# For epoch 8 the test accuracy over the whole test set is 0 %
# Prediction data is: [125.2986]
# label data is:  [[165.5]
#  [ 92. ]
#  [ 85. ]
#  [ 52. ]
#  [ 27. ]]
# epoch: 0 loss: 649.4589233398438
# Prediction data is: [52.34526]
# label data is:  [[77.]
#  [54.]
#  [61.]
#  [26.]
#  [55.]]
# epoch: 8 loss: 254.1944580078125
# Prediction data is: [44.88777]
# label data is:  [[ 44. ]
#  [ 20.5]
#  [ 48. ]
#  [166. ]
#  [170. ]]
# epoch: 16 loss: 2726.940185546875
# Prediction data is: [56.06309]
# label data is:  [[ 64. ]
#  [ 34. ]
#  [102. ]
#  [ 90. ]
#  [ 29.5]]
# epoch: 24 loss: 954.9421997070312
# Prediction data is: [78.30753]
# label data is:  [[150.]
#  [140.]
#  [ 82.]
#  [ 83.]
#  [ 96.]]
# epoch: 32 loss: 2448.565185546875
# Prediction data is: [57.712135]
# label data is:  [[ 80.5]
#  [105. ]
#  [172.5]
#  [ 38. ]
#  [ 49.5]]
# epoch: 40 loss: 935.2542114257812
# Prediction data is: [69.92264]
# label data is:  [[ 30.]
#  [ 61.]
#  [146.]
#  [ 90.]
#  [154.]]
# epoch: 48 loss: 3711.699951171875
# Prediction data is: [69.54797]
# label data is:  [[ 88. ]
#  [144.5]
#  [161. ]
#  [ 20. ]
#  [133. ]]
# epoch: 56 loss: 470.0196838378906
# Prediction data is: [152.3951]
# label data is:  [[110.]
#  [ 40.]
#  [ 86.]
#  [ 29.]
#  [126.]]
# epoch: 64 loss: 2160.45361328125
# Prediction data is: [84.65173]
# label data is:  [[ 65. ]
#  [122. ]
#  [111. ]
#  [111. ]
#  [ 56.5]]
# epoch: 72 loss: 2024.244140625
# Prediction data is: [90.85772]
# label data is:  [[ 68.]
#  [108.]
#  [ 81.]
#  [127.]
#  [ 79.]]
# epoch: 80 loss: 294.8522033691406
# Prediction data is: [97.0175]
# label data is:  [[26.]
#  [ 0.]
#  [74.]
#  [72.]
#  [59.]]
# epoch: 88 loss: 1972.9691162109375
# Prediction data is: [74.83044]
# label data is:  [[103. ]
#  [124. ]
#  [ 62. ]
#  [ 40.5]
#  [ 84. ]]
# epoch: 96 loss: 907.2376098632812
# Prediction data is: [76.14373]
# label data is:  [[ 86. ]
#  [120. ]
#  [140.5]
#  [ 35. ]
#  [165. ]]
# epoch: 104 loss: 2352.0859375
# Prediction data is: [70.58999]
# label data is:  [[ 43. ]
#  [ 45.5]
#  [ 63. ]
#  [ 42. ]
#  [175. ]]
# epoch: 112 loss: 1322.5244140625
# Prediction data is: [63.84866]
# label data is:  [[140.]
#  [ 28.]
#  [ 47.]
#  [100.]
#  [124.]]
# epoch: 120 loss: 2268.8056640625
# Prediction data is: [76.071526]
# label data is:  [[ 68.]
#  [150.]
#  [ 28.]
#  [107.]
#  [ 39.]]
# epoch: 128 loss: 746.4960327148438
# Prediction data is: [70.937996]
# label data is:  [[133.]
#  [107.]
#  [119.]
#  [160.]
#  [ 81.]]
# epoch: 136 loss: 1665.9930419921875
# Prediction data is: [80.582855]
# label data is:  [[  8. ]
#  [ 76. ]
#  [ 25. ]
#  [135. ]
#  [116.5]]
# epoch: 144 loss: 2450.238037109375
# Prediction data is: [92.39141]
# label data is:  [[124. ]
#  [130. ]
#  [ 59.5]
#  [ 95. ]
#  [ 56.5]]
# epoch: 152 loss: 828.65625
# Prediction data is: [90.75548]
# label data is:  [[ 50. ]
#  [132. ]
#  [137.5]
#  [ 37. ]
#  [ 72. ]]
# epoch: 160 loss: 1149.2659912109375
# Prediction data is: [104.028206]
# label data is:  [[ 99.]
#  [ 67.]
#  [ 59.]
#  [115.]
#  [135.]]
# epoch: 168 loss: 874.0011596679688
# Prediction data is: [108.04947]
# label data is:  [[138. ]
#  [ 81.5]
#  [ 36. ]
#  [129. ]
#  [146. ]]
# epoch: 176 loss: 1549.0389404296875
# Prediction data is: [115.4124]
# label data is:  [[150.5]
#  [ 37. ]
#  [ 92. ]
#  [ 49.5]
#  [ 74. ]]
# epoch: 184 loss: 2772.276611328125
# Prediction data is: [128.32011]
# label data is:  [[116. ]
#  [ 72. ]
#  [ 52. ]
#  [118. ]
#  [ 35.5]]
# epoch: 192 loss: 1814.1044921875
# Prediction data is: [103.76958]
# label data is:  [[158. ]
#  [105.5]
#  [ 75. ]
#  [146. ]
#  [113.5]]
# epoch: 200 loss: 832.9115600585938
# Prediction data is: [91.14139]
# label data is:  [[108. ]
#  [164. ]
#  [ 45.5]
#  [155. ]
#  [ 24.5]]
# epoch: 208 loss: 2291.952880859375
# Prediction data is: [89.83539]
# label data is:  [[ 94. ]
#  [ 97. ]
#  [ 41.5]
#  [ 45. ]
#  [154. ]]
# epoch: 216 loss: 1448.0819091796875
# Prediction data is: [80.648796]
# label data is:  [[ 91. ]
#  [178. ]
#  [ 78. ]
#  [ 22.5]
#  [ 97.5]]
# epoch: 224 loss: 917.6612548828125
# Prediction data is: [70.27605]
# label data is:  [[ 47.5]
#  [143. ]
#  [ 51. ]
#  [ 66. ]
#  [ 95.5]]
# epoch: 232 loss: 1069.9090576171875
# Prediction data is: [67.31315]
# label data is:  [[42.]
#  [58.]
#  [96.]
#  [33.]]
# epoch: 240 loss: 663.9185180664062
# For epoch 9 the test accuracy over the whole test set is 0 %
# Prediction data is: [69.04977]
# label data is:  [[ 67.]
#  [ 92.]
#  [ 26.]
#  [126.]
#  [175.]]
# epoch: 0 loss: 1793.451416015625
# Prediction data is: [32.274746]
# label data is:  [[ 28. ]
#  [150. ]
#  [161. ]
#  [108. ]
#  [ 97.5]]
# epoch: 9 loss: 2349.709716796875
# Prediction data is: [116.826584]
# label data is:  [[113.5]
#  [ 54. ]
#  [129. ]
#  [ 78. ]
#  [111. ]]
# epoch: 18 loss: 268.5169982910156
# Prediction data is: [107.81238]
# label data is:  [[82. ]
#  [86. ]
#  [20.5]
#  [42. ]
#  [22.5]]
# epoch: 27 loss: 1541.594482421875
# Prediction data is: [81.986694]
# label data is:  [[115.]
#  [119.]
#  [108.]
#  [ 83.]
#  [166.]]
# epoch: 36 loss: 797.1484985351562
# Prediction data is: [114.619705]
# label data is:  [[ 43. ]
#  [127. ]
#  [146. ]
#  [ 50. ]
#  [137.5]]
# epoch: 45 loss: 2242.821533203125
# Prediction data is: [128.18605]
# label data is:  [[158. ]
#  [ 96. ]
#  [160. ]
#  [124. ]
#  [ 95.5]]
# epoch: 54 loss: 824.5089111328125
# Prediction data is: [139.30472]
# label data is:  [[105.5]
#  [ 51. ]
#  [143. ]
#  [ 61. ]
#  [133. ]]
# epoch: 63 loss: 1363.33984375
# Prediction data is: [96.65989]
# label data is:  [[132. ]
#  [ 41.5]
#  [ 35.5]
#  [ 47.5]
#  [ 39. ]]
# epoch: 72 loss: 1371.2254638671875
# Prediction data is: [111.04476]
# label data is:  [[ 64.]
#  [100.]
#  [ 85.]
#  [  0.]
#  [107.]]
# epoch: 81 loss: 710.7457885742188
# Prediction data is: [78.91266]
# label data is:  [[ 63.]
#  [ 72.]
#  [111.]
#  [164.]
#  [105.]]
# epoch: 90 loss: 383.89776611328125
# Prediction data is: [92.884544]
# label data is:  [[ 80.5]
#  [ 97. ]
#  [ 56.5]
#  [150. ]
#  [ 52. ]]
# epoch: 99 loss: 676.9027709960938
# Prediction data is: [84.89684]
# label data is:  [[102. ]
#  [ 44. ]
#  [ 68. ]
#  [140. ]
#  [ 49.5]]
# epoch: 108 loss: 2965.176513671875
# Prediction data is: [106.260506]
# label data is:  [[ 94. ]
#  [116.5]
#  [ 79. ]
#  [ 29. ]
#  [ 55. ]]
# epoch: 117 loss: 468.52471923828125
# Prediction data is: [88.57353]
# label data is:  [[ 95. ]
#  [ 84. ]
#  [ 88. ]
#  [107. ]
#  [ 29.5]]
# epoch: 126 loss: 395.05621337890625
# Prediction data is: [59.646095]
# label data is:  [[135. ]
#  [ 62. ]
#  [110. ]
#  [ 24.5]
#  [150.5]]
# epoch: 135 loss: 2795.53515625
# Prediction data is: [47.82157]
# label data is:  [[ 75.]
#  [ 72.]
#  [ 65.]
#  [155.]
#  [ 47.]]
# epoch: 144 loss: 542.5912475585938
# Prediction data is: [32.921753]
# label data is:  [[35.]
#  [25.]
#  [28.]
#  [40.]
#  [37.]]
# epoch: 153 loss: 695.3009643554688
# Prediction data is: [50.99252]
# label data is:  [[49.5]
#  [74. ]
#  [33. ]
#  [56.5]
#  [37. ]]
# epoch: 162 loss: 151.2630615234375
# Prediction data is: [49.221165]
# label data is:  [[ 26.]
#  [170.]
#  [ 61.]
#  [ 81.]
#  [ 34.]]
# epoch: 171 loss: 1845.7562255859375
# Prediction data is: [52.798508]
# label data is:  [[118.]
#  [146.]
#  [ 38.]
#  [124.]
#  [ 91.]]
# epoch: 180 loss: 2444.440673828125
# Prediction data is: [50.837364]
# label data is:  [[ 40.5]
#  [103. ]
#  [ 58. ]
#  [ 68. ]
#  [ 59. ]]
# epoch: 189 loss: 467.72662353515625
# Prediction data is: [60.455303]
# label data is:  [[120. ]
#  [144.5]
#  [  8. ]
#  [130. ]
#  [ 30. ]]
# epoch: 198 loss: 2427.74609375
# Prediction data is: [64.6769]
# label data is:  [[ 59.]
#  [ 96.]
#  [178.]
#  [140.]
#  [124.]]
# epoch: 207 loss: 1450.091064453125
# Prediction data is: [76.87578]
# label data is:  [[135. ]
#  [154. ]
#  [165.5]
#  [ 45.5]
#  [ 76. ]]
# epoch: 216 loss: 2109.394287109375
# Prediction data is: [90.72135]
# label data is:  [[138. ]
#  [172.5]
#  [ 99. ]
#  [ 86. ]
#  [133. ]]
# epoch: 225 loss: 602.316162109375
# Prediction data is: [100.498924]
# label data is:  [[ 52. ]
#  [116. ]
#  [ 20. ]
#  [ 90. ]
#  [ 45.5]]
# epoch: 234 loss: 1763.8187255859375
# Prediction data is: [132.79106]
# label data is:  [[45.]
#  [74.]
#  [81.]
#  [90.]
#  [42.]]
# epoch: 243 loss: 2786.775390625
# Prediction data is: [57.609745]
# label data is:  [[ 48. ]
#  [122. ]
#  [ 92. ]
#  [ 59.5]
#  [140.5]]
# epoch: 252 loss: 560.72021484375
# Prediction data is: [95.13297]
# label data is:  [[146.]
#  [ 36.]
#  [ 77.]
#  [ 72.]
#  [154.]]
# epoch: 261 loss: 1317.1673583984375
# Prediction data is: [79.27686]
# label data is:  [[ 27. ]
#  [ 66. ]
#  [165. ]
#  [ 81.5]]
# epoch: 270 loss: 938.9848022460938
# For epoch 10 the test accuracy over the whole test set is 0 %
# Prediction data is: [88.991165]
# label data is:  [[ 45. ]
#  [ 50. ]
#  [116.5]
#  [135. ]
#  [ 81. ]]
# epoch: 0 loss: 1153.9033203125
# Prediction data is: [75.5508]
# label data is:  [[54.]
#  [95.]
#  [90.]
#  [42.]
#  [34.]]
# epoch: 10 loss: 615.5367431640625
# Prediction data is: [63.016415]
# label data is:  [[108. ]
#  [158. ]
#  [ 56.5]
#  [124. ]
#  [ 49.5]]
# epoch: 20 loss: 2286.8984375
# Prediction data is: [54.99699]
# label data is:  [[ 58.]
#  [103.]
#  [ 39.]
#  [ 52.]
#  [ 59.]]
# epoch: 30 loss: 316.21514892578125
# Prediction data is: [62.404274]
# label data is:  [[146. ]
#  [ 37. ]
#  [143. ]
#  [ 41.5]
#  [107. ]]
# epoch: 40 loss: 3117.671630859375
# Prediction data is: [123.2305]
# label data is:  [[165. ]
#  [111. ]
#  [129. ]
#  [ 20.5]
#  [ 61. ]]
# epoch: 50 loss: 1581.6474609375
# Prediction data is: [62.45848]
# label data is:  [[ 72. ]
#  [ 74. ]
#  [113.5]
#  [116. ]
#  [146. ]]
# epoch: 60 loss: 1279.7740478515625
# Prediction data is: [122.13597]
# label data is:  [[170. ]
#  [ 56.5]
#  [ 75. ]
#  [ 99. ]
#  [ 81.5]]
# epoch: 70 loss: 598.9417114257812
# Prediction data is: [123.394424]
# label data is:  [[ 68.]
#  [ 65.]
#  [ 92.]
#  [133.]
#  [ 92.]]
# epoch: 80 loss: 683.8012084960938
# Prediction data is: [92.09886]
# label data is:  [[120. ]
#  [ 95.5]
#  [ 84. ]
#  [140.5]
#  [122. ]]
# epoch: 90 loss: 543.9151000976562
# Prediction data is: [155.66643]
# label data is:  [[166. ]
#  [135. ]
#  [ 43. ]
#  [ 26. ]
#  [105.5]]
# epoch: 100 loss: 3285.711669921875
# Prediction data is: [100.8452]
# label data is:  [[102. ]
#  [ 96. ]
#  [ 35.5]
#  [127. ]
#  [137.5]]
# epoch: 110 loss: 930.7260131835938
# Prediction data is: [169.29938]
# label data is:  [[155.]
#  [ 42.]
#  [ 38.]
#  [ 86.]
#  [124.]]
# epoch: 120 loss: 796.6961059570312
# Prediction data is: [85.60913]
# label data is:  [[ 55. ]
#  [ 47.5]
#  [ 72. ]
#  [165.5]
#  [ 94. ]]
# epoch: 130 loss: 604.4972534179688
# Prediction data is: [74.66171]
# label data is:  [[63.]
#  [ 0.]
#  [ 8.]
#  [90.]
#  [72.]]
# epoch: 140 loss: 1428.4652099609375
# Prediction data is: [75.35374]
# label data is:  [[ 61.]
#  [ 27.]
#  [178.]
#  [140.]
#  [ 81.]]
# epoch: 150 loss: 1475.92578125
# Prediction data is: [81.5504]
# label data is:  [[164.]
#  [ 37.]
#  [ 33.]
#  [ 25.]
#  [ 36.]]
# epoch: 160 loss: 2081.886474609375
# Prediction data is: [59.488876]
# label data is:  [[ 91. ]
#  [110. ]
#  [ 24.5]
#  [ 26. ]
#  [140. ]]
# epoch: 170 loss: 1879.2049560546875
# Prediction data is: [23.52628]
# label data is:  [[ 28. ]
#  [146. ]
#  [ 67. ]
#  [ 66. ]
#  [ 59.5]]
# epoch: 180 loss: 862.3404541015625
# Prediction data is: [46.386524]
# label data is:  [[ 44.]
#  [ 74.]
#  [133.]
#  [160.]
#  [132.]]
# epoch: 190 loss: 2852.177001953125
# Prediction data is: [58.66911]
# label data is:  [[ 68. ]
#  [ 20. ]
#  [161. ]
#  [ 77. ]
#  [ 49.5]]
# epoch: 200 loss: 1860.4344482421875
# Prediction data is: [63.523216]
# label data is:  [[138. ]
#  [ 62. ]
#  [ 64. ]
#  [ 28. ]
#  [ 97.5]]
# epoch: 210 loss: 1573.0203857421875
# Prediction data is: [83.61993]
# label data is:  [[ 86.]
#  [154.]
#  [154.]
#  [150.]
#  [130.]]
# epoch: 220 loss: 3375.53369140625
# Prediction data is: [72.822685]
# label data is:  [[ 45.5]
#  [ 88. ]
#  [107. ]
#  [105. ]
#  [ 51. ]]
# epoch: 230 loss: 313.704345703125
# Prediction data is: [94.24867]
# label data is:  [[ 45.5]
#  [ 35. ]
#  [ 29. ]
#  [126. ]
#  [ 30. ]]
# epoch: 240 loss: 2375.543701171875
# Prediction data is: [90.08848]
# label data is:  [[ 40.5]
#  [ 97. ]
#  [119. ]
#  [175. ]
#  [108. ]]
# epoch: 250 loss: 1043.2813720703125
# Prediction data is: [107.37917]
# label data is:  [[ 80.5]
#  [ 52. ]
#  [ 78. ]
#  [ 48. ]
#  [144.5]]
# epoch: 260 loss: 1638.7137451171875
# Prediction data is: [117.13241]
# label data is:  [[150.5]
#  [115. ]
#  [ 40. ]
#  [ 79. ]
#  [172.5]]
# epoch: 270 loss: 1183.2308349609375
# Prediction data is: [107.85388]
# label data is:  [[ 83. ]
#  [111. ]
#  [ 96. ]
#  [ 29.5]
#  [ 76. ]]
# epoch: 280 loss: 1010.6596069335938
# Prediction data is: [71.649055]
# label data is:  [[ 85.]
#  [ 47.]
#  [ 59.]
#  [124.]
#  [ 82.]]
# epoch: 290 loss: 586.5496826171875
# Prediction data is: [100.309845]
# label data is:  [[150. ]
#  [ 22.5]
#  [118. ]
#  [100. ]]
# epoch: 300 loss: 2146.02734375
# For epoch 11 the test accuracy over the whole test set is 0 %
# Prediction data is: [67.24934]
# label data is:  [[ 34.]
#  [155.]
#  [146.]
#  [ 45.]
#  [140.]]
# epoch: 0 loss: 3182.31005859375
# Prediction data is: [81.50306]
# label data is:  [[111. ]
#  [ 99. ]
#  [164. ]
#  [ 29.5]
#  [ 47. ]]
# epoch: 11 loss: 2306.046630859375
# Prediction data is: [61.61769]
# label data is:  [[ 28.]
#  [124.]
#  [ 91.]
#  [ 78.]
#  [ 82.]]
# epoch: 22 loss: 911.2380981445312
# Prediction data is: [56.17761]
# label data is:  [[81. ]
#  [49.5]
#  [45.5]
#  [42. ]
#  [81.5]]
# epoch: 33 loss: 344.4437561035156
# Prediction data is: [60.07042]
# label data is:  [[ 52.]
#  [135.]
#  [ 54.]
#  [ 36.]
#  [135.]]
# epoch: 44 loss: 2331.177490234375
# Prediction data is: [101.81863]
# label data is:  [[170. ]
#  [ 42. ]
#  [  8. ]
#  [ 35.5]
#  [140.5]]
# epoch: 55 loss: 2751.10595703125
# Prediction data is: [74.08371]
# label data is:  [[115. ]
#  [ 61. ]
#  [ 68. ]
#  [ 64. ]
#  [ 24.5]]
# epoch: 66 loss: 881.8051147460938
# Prediction data is: [76.152374]
# label data is:  [[138. ]
#  [ 55. ]
#  [ 40.5]
#  [ 37. ]
#  [ 56.5]]
# epoch: 77 loss: 1767.404296875
# Prediction data is: [71.029465]
# label data is:  [[ 41.5]
#  [ 67. ]
#  [122. ]
#  [ 20.5]
#  [ 50. ]]
# epoch: 88 loss: 916.9220581054688
# Prediction data is: [110.32062]
# label data is:  [[158. ]
#  [ 26. ]
#  [113.5]
#  [100. ]
#  [ 39. ]]
# epoch: 99 loss: 917.2590942382812
# Prediction data is: [40.89857]
# label data is:  [[ 37.]
#  [108.]
#  [ 84.]
#  [ 90.]
#  [ 86.]]
# epoch: 110 loss: 373.3923034667969
# Prediction data is: [73.6467]
# label data is:  [[ 74.]
#  [130.]
#  [ 62.]
#  [143.]
#  [ 26.]]
# epoch: 121 loss: 2263.550537109375
# Prediction data is: [113.75715]
# label data is:  [[124. ]
#  [146. ]
#  [127. ]
#  [ 65. ]
#  [ 45.5]]
# epoch: 132 loss: 1252.702880859375
# Prediction data is: [100.31595]
# label data is:  [[ 94. ]
#  [ 47.5]
#  [116. ]
#  [137.5]
#  [116.5]]
# epoch: 143 loss: 415.5396423339844
# Prediction data is: [43.09416]
# label data is:  [[ 28.]
#  [178.]
#  [ 58.]
#  [ 29.]
#  [102.]]
# epoch: 154 loss: 612.0927734375
# Prediction data is: [85.06957]
# label data is:  [[132. ]
#  [ 22.5]
#  [110. ]
#  [ 59. ]
#  [124. ]]
# epoch: 165 loss: 1750.1077880859375
# Prediction data is: [78.711006]
# label data is:  [[ 77. ]
#  [ 86. ]
#  [133. ]
#  [105.5]
#  [150. ]]
# epoch: 176 loss: 683.786376953125
# Prediction data is: [116.10821]
# label data is:  [[150. ]
#  [111. ]
#  [ 43. ]
#  [ 59.5]
#  [108. ]]
# epoch: 187 loss: 1354.9771728515625
# Prediction data is: [73.62864]
# label data is:  [[75.]
#  [48.]
#  [74.]
#  [25.]
#  [97.]]
# epoch: 198 loss: 651.0228881835938
# Prediction data is: [89.5872]
# label data is:  [[ 76.]
#  [ 63.]
#  [133.]
#  [ 92.]
#  [146.]]
# epoch: 209 loss: 812.99951171875
# Prediction data is: [77.40114]
# label data is:  [[ 52.]
#  [ 79.]
#  [175.]
#  [165.]
#  [166.]]
# epoch: 220 loss: 488.0716857910156
# Prediction data is: [71.13856]
# label data is:  [[ 44. ]
#  [ 27. ]
#  [ 30. ]
#  [150.5]
#  [ 56.5]]
# epoch: 231 loss: 2087.91259765625
# Prediction data is: [125.922585]
# label data is:  [[154. ]
#  [ 61. ]
#  [144.5]
#  [140. ]
#  [ 85. ]]
# epoch: 242 loss: 1429.335205078125
# Prediction data is: [97.08076]
# label data is:  [[ 90. ]
#  [ 97.5]
#  [ 51. ]
#  [ 68. ]
#  [165.5]]
# epoch: 253 loss: 679.1844482421875
# Prediction data is: [78.90666]
# label data is:  [[ 40.]
#  [ 38.]
#  [107.]
#  [ 59.]
#  [ 72.]]
# epoch: 264 loss: 753.2388305664062
# Prediction data is: [80.95106]
# label data is:  [[ 95.]
#  [ 83.]
#  [ 72.]
#  [154.]
#  [ 20.]]
# epoch: 275 loss: 1580.0096435546875
# Prediction data is: [68.502426]
# label data is:  [[ 95.5]
#  [161. ]
#  [ 35. ]
#  [107. ]
#  [160. ]]
# epoch: 286 loss: 1256.2362060546875
# Prediction data is: [71.54605]
# label data is:  [[ 80.5]
#  [129. ]
#  [  0. ]
#  [ 49.5]
#  [ 92. ]]
# epoch: 297 loss: 248.9641571044922
# Prediction data is: [86.82121]
# label data is:  [[ 66.]
#  [126.]
#  [103.]
#  [119.]
#  [ 72.]]
# epoch: 308 loss: 778.052978515625
# Prediction data is: [73.75277]
# label data is:  [[120.]
#  [ 33.]
#  [ 88.]
#  [118.]
#  [ 96.]]
# epoch: 319 loss: 990.421875
# Prediction data is: [181.94246]
# label data is:  [[172.5]
#  [105. ]
#  [ 96. ]
#  [ 81. ]]
# epoch: 330 loss: 239.71151733398438
# For epoch 12 the test accuracy over the whole test set is 0 %
# Prediction data is: [76.66576]
# label data is:  [[44. ]
#  [97.5]
#  [68. ]
#  [25. ]
#  [28. ]]
# epoch: 0 loss: 1801.391845703125
# Prediction data is: [144.20255]
# label data is:  [[116.]
#  [ 30.]
#  [  0.]
#  [ 81.]
#  [ 40.]]
# epoch: 12 loss: 1463.782470703125
# Prediction data is: [170.17232]
# label data is:  [[172.5]
#  [ 20. ]
#  [ 20.5]
#  [ 36. ]
#  [ 61. ]]
# epoch: 24 loss: 1011.2094116210938
# Prediction data is: [69.76532]
# label data is:  [[92.]
#  [90.]
#  [91.]
#  [59.]
#  [90.]]
# epoch: 36 loss: 255.2825164794922
# Prediction data is: [63.77887]
# label data is:  [[ 88. ]
#  [ 99. ]
#  [150. ]
#  [122. ]
#  [ 29.5]]
# epoch: 48 loss: 700.4892578125
# Prediction data is: [52.83805]
# label data is:  [[ 78. ]
#  [ 28. ]
#  [116.5]
#  [ 42. ]
#  [ 49.5]]
# epoch: 60 loss: 403.8655700683594
# Prediction data is: [19.185387]
# label data is:  [[ 51. ]
#  [120. ]
#  [ 49.5]
#  [111. ]
#  [124. ]]
# epoch: 72 loss: 1409.5975341796875
# Prediction data is: [63.438087]
# label data is:  [[140.]
#  [ 61.]
#  [135.]
#  [ 37.]
# ...
# label data is:  [[ 54. ]
#  [140.5]
#  [ 94. ]
#  [ 86. ]
#  [ 67. ]]
# epoch: 52 loss: 817.03076171875
# Prediction data is: [137.86876]
# label data is:  [[105.5]
#  [146. ]
#  [ 92. ]
#  [108. ]
#  [ 35. ]]
# epoch: 78 loss: 232.53929138183594
# Prediction data is: [52.11056]
# label data is:  [[ 24.5]
#  [178. ]
#  [ 20. ]
#  [ 52. ]
#  [ 27. ]]
# epoch: 104 loss: 332.1784362792969
# Prediction data is: [52.70876]
# label data is:  [[ 49.5]
#  [ 81.5]
#  [ 56.5]
#  [ 25. ]
#  [175. ]]
# epoch: 130 loss: 423.5937194824219
# Prediction data is: [107.66758]
# label data is:  [[115. ]
#  [158. ]
#  [107. ]
#  [ 66. ]
#  [ 22.5]]
# epoch: 156 loss: 662.0426635742188
# Prediction data is: [90.64051]
# label data is:  [[82. ]
#  [49.5]
#  [95.5]
#  [26. ]
#  [64. ]]
# epoch: 182 loss: 222.4740753173828
# Prediction data is: [106.170654]
# label data is:  [[164.]
#  [ 74.]
#  [116.]
#  [140.]
#  [ 34.]]
# epoch: 208 loss: 1547.1630859375
# Prediction data is: [112.021385]
# label data is:  [[133. ]
#  [160. ]
#  [ 37. ]
#  [116.5]
#  [ 80.5]]
# epoch: 234 loss: 144.81517028808594
# Prediction data is: [96.28941]
# label data is:  [[ 88.]
#  [ 38.]
#  [135.]
#  [ 42.]
#  [111.]]
# epoch: 260 loss: 199.75445556640625
# Prediction data is: [30.35031]
# label data is:  [[ 28.]
#  [155.]
#  [ 84.]
#  [138.]
#  [143.]]
# epoch: 286 loss: 1393.8031005859375
# Prediction data is: [114.904]
# label data is:  [[97. ]
#  [ 8. ]
#  [55. ]
#  [79. ]
#  [47.5]]
# epoch: 312 loss: 1196.2645263671875
# Prediction data is: [83.67006]
# label data is:  [[ 41.5]
#  [ 72. ]
#  [165. ]
#  [ 56.5]
#  [161. ]]
# epoch: 338 loss: 775.6615600585938
# Prediction data is: [101.44088]
# label data is:  [[ 74. ]
#  [140. ]
#  [137.5]
#  [146. ]
#  [ 40.5]]
# epoch: 364 loss: 425.78375244140625
# Prediction data is: [47.027348]
# label data is:  [[ 58.]
#  [ 81.]
#  [110.]
#  [122.]
#  [ 81.]]
# epoch: 390 loss: 100.52159118652344
# Prediction data is: [125.30445]
# label data is:  [[ 96. ]
#  [133. ]
#  [113.5]
#  [ 29.5]
#  [ 51. ]]
# epoch: 416 loss: 1213.8824462890625
# Prediction data is: [107.55135]
# label data is:  [[118.]
#  [130.]
#  [ 86.]
#  [ 96.]
#  [ 44.]]
# epoch: 442 loss: 419.5956726074219
# Prediction data is: [4.192585]
# label data is:  [[  0.]
#  [ 33.]
#  [108.]
#  [ 68.]
#  [ 92.]]
# epoch: 468 loss: 325.84124755859375
# Prediction data is: [120.7443]
# label data is:  [[124. ]
#  [102. ]
#  [ 43. ]
#  [150. ]
#  [ 59.5]]
# epoch: 494 loss: 483.9436950683594
# Prediction data is: [32.477272]
# label data is:  [[ 29.]
#  [126.]
#  [ 99.]
#  [119.]
#  [ 42.]]
# epoch: 520 loss: 655.9426879882812
# Prediction data is: [65.09162]
# label data is:  [[ 85. ]
#  [146. ]
#  [ 45.5]
#  [ 97.5]
#  [ 63. ]]
# epoch: 546 loss: 991.4545288085938
# Prediction data is: [120.453636]
# label data is:  [[150. ]
#  [ 90. ]
#  [154. ]
#  [144.5]
#  [ 76. ]]
# epoch: 572 loss: 254.8551483154297
# Prediction data is: [143.12614]
# label data is:  [[166.]
#  [ 65.]
#  [111.]
#  [ 39.]
#  [ 83.]]
# epoch: 598 loss: 436.13134765625
# Prediction data is: [103.08238]
# label data is:  [[ 52.]
#  [100.]
#  [ 50.]
#  [ 78.]
#  [ 45.]]
# epoch: 624 loss: 761.5097045898438
# Prediction data is: [64.33701]
# label data is:  [[ 59. ]
#  [ 20.5]
#  [ 90. ]
#  [ 36. ]
#  [150.5]]
# epoch: 650 loss: 438.62432861328125
# Prediction data is: [67.85532]
# label data is:  [[ 47.]
#  [103.]
#  [ 61.]
#  [ 30.]
#  [105.]]
# epoch: 676 loss: 589.4989624023438
# Prediction data is: [127.03494]
# label data is:  [[124. ]
#  [127. ]
#  [ 61. ]
#  [ 95. ]
#  [ 35.5]]
# epoch: 702 loss: 380.7006530761719
# Prediction data is: [26.619495]
# label data is:  [[ 26.]
#  [ 77.]
#  [ 72.]
#  [ 72.]
#  [107.]]
# epoch: 728 loss: 450.140869140625
# Prediction data is: [74.155174]
# label data is:  [[ 91. ]
#  [124. ]
#  [170. ]
#  [ 45.5]
#  [172.5]]
# epoch: 754 loss: 799.2088623046875
# Prediction data is: [22.520012]
# label data is:  [[ 28.]
#  [120.]
#  [ 40.]
#  [ 68.]]
# epoch: 780 loss: 723.087646484375
# For epoch 27 the test accuracy over the whole test set is 0 %
# Prediction data is: [82.14047]
# label data is:  [[ 94. ]
#  [  8. ]
#  [ 49.5]
#  [160. ]
#  [111. ]]
# epoch: 0 loss: 612.6968994140625
# Prediction data is: [109.47812]
# label data is:  [[119. ]
#  [107. ]
#  [ 68. ]
#  [ 75. ]
#  [ 81.5]]
# epoch: 27 loss: 263.4211120605469
# Prediction data is: [97.92018]
# label data is:  [[146.]
#  [ 29.]
#  [133.]
#  [ 26.]
#  [ 59.]]
# epoch: 54 loss: 831.3435668945312
# Prediction data is: [49.55583]
# label data is:  [[ 47.]
#  [170.]
#  [ 52.]
#  [ 72.]
#  [138.]]
# epoch: 81 loss: 542.55126953125
# Prediction data is: [161.90733]
# label data is:  [[150. ]
#  [ 56.5]
#  [165. ]
#  [115. ]
#  [ 61. ]]
# epoch: 108 loss: 52.543941497802734
# Prediction data is: [41.76315]
# label data is:  [[ 33. ]
#  [ 36. ]
#  [ 95.5]
#  [ 30. ]
#  [133. ]]
# epoch: 135 loss: 173.638671875
# Prediction data is: [172.40155]
# label data is:  [[105.5]
#  [ 54. ]
#  [ 95. ]
#  [172.5]
#  [ 55. ]]
# epoch: 162 loss: 1894.4442138671875
# Prediction data is: [145.58398]
# label data is:  [[164. ]
#  [ 64. ]
#  [140. ]
#  [ 35.5]
#  [150.5]]
# epoch: 189 loss: 713.8143920898438
# Prediction data is: [124.365974]
# label data is:  [[74. ]
#  [59.5]
#  [28. ]
#  [86. ]
#  [42. ]]
# epoch: 216 loss: 586.4402465820312
# Prediction data is: [48.36683]
# label data is:  [[ 35. ]
#  [178. ]
#  [ 56.5]
#  [146. ]
#  [ 28. ]]
# epoch: 243 loss: 634.7891845703125
# Prediction data is: [31.297142]
# label data is:  [[ 20.5]
#  [137.5]
#  [ 37. ]
#  [ 51. ]
#  [ 22.5]]
# epoch: 270 loss: 238.597412109375
# Prediction data is: [124.8522]
# label data is:  [[158.]
#  [ 99.]
#  [ 85.]
#  [ 88.]
#  [ 96.]]
# epoch: 297 loss: 314.1061096191406
# Prediction data is: [100.451996]
# label data is:  [[ 68.]
#  [ 44.]
#  [ 74.]
#  [103.]
#  [ 42.]]
# epoch: 324 loss: 280.646728515625
# Prediction data is: [111.78743]
# label data is:  [[116.5]
#  [130. ]
#  [ 40.5]
#  [124. ]
#  [ 72. ]]
# epoch: 351 loss: 774.0015869140625
# Prediction data is: [62.848877]
# label data is:  [[143.]
#  [ 90.]
#  [154.]
#  [116.]
#  [ 61.]]
# epoch: 378 loss: 1554.6038818359375
# Prediction data is: [38.67686]
# label data is:  [[ 24.5]
#  [ 83. ]
#  [154. ]
#  [ 81. ]
#  [140.5]]
# epoch: 405 loss: 819.8511962890625
# Prediction data is: [143.22337]
# label data is:  [[129. ]
#  [ 63. ]
#  [166. ]
#  [ 79. ]
#  [ 45.5]]
# epoch: 432 loss: 962.8693237304688
# Prediction data is: [108.79989]
# label data is:  [[ 97.5]
#  [102. ]
#  [100. ]
#  [ 59. ]
#  [127. ]]
# epoch: 459 loss: 395.8664245605469
# Prediction data is: [71.436966]
# label data is:  [[43.]
#  [27.]
#  [92.]
#  [50.]
#  [66.]]
# epoch: 486 loss: 1326.905517578125
# Prediction data is: [132.99004]
# label data is:  [[132. ]
#  [ 34. ]
#  [135. ]
#  [ 80.5]
#  [113.5]]
# epoch: 513 loss: 317.3100280761719
# Prediction data is: [126.74384]
# label data is:  [[161.]
#  [ 62.]
#  [ 58.]
#  [118.]
#  [150.]]
# epoch: 540 loss: 397.13702392578125
# Prediction data is: [42.899563]
# label data is:  [[40. ]
#  [ 0. ]
#  [45. ]
#  [47.5]
#  [67. ]]
# epoch: 567 loss: 408.30035400390625
# Prediction data is: [92.397514]
# label data is:  [[135. ]
#  [140. ]
#  [ 92. ]
#  [ 41.5]
#  [ 76. ]]
# epoch: 594 loss: 1257.0177001953125
# Prediction data is: [82.275635]
# label data is:  [[ 29.5]
#  [124. ]
#  [ 78. ]
#  [175. ]
#  [ 49.5]]
# epoch: 621 loss: 1211.4964599609375
# Prediction data is: [92.35281]
# label data is:  [[108.]
#  [122.]
#  [ 25.]
#  [ 39.]
#  [ 37.]]
# epoch: 648 loss: 192.4630584716797
# Prediction data is: [76.62947]
# label data is:  [[ 90. ]
#  [105. ]
#  [ 52. ]
#  [144.5]
#  [ 86. ]]
# epoch: 675 loss: 80.61827850341797
# Prediction data is: [104.23972]
# label data is:  [[110.]
#  [ 77.]
#  [107.]
#  [ 96.]
#  [ 48.]]
# epoch: 702 loss: 106.13750457763672
# Prediction data is: [48.55476]
# label data is:  [[ 65. ]
#  [111. ]
#  [ 97. ]
#  [165.5]
#  [146. ]]
# epoch: 729 loss: 263.5033874511719
# Prediction data is: [79.78576]
# label data is:  [[ 81.]
#  [108.]
#  [ 84.]
#  [ 72.]
#  [124.]]
# epoch: 756 loss: 98.07776641845703
# Prediction data is: [30.566109]
# label data is:  [[ 20.]
#  [ 26.]
#  [126.]
#  [ 91.]
#  [ 82.]]
# epoch: 783 loss: 117.3769760131836
# Prediction data is: [38.922016]
# label data is:  [[ 38. ]
#  [120. ]
#  [ 45.5]
#  [155. ]]
# epoch: 810 loss: 72.21198272705078
# For epoch 28 the test accuracy over the whole test set is 0 %
# Prediction data is: [39.33479]
# label data is:  [[ 37.]
#  [ 84.]
#  [  0.]
#  [150.]
#  [ 33.]]
# epoch: 0 loss: 118.7051773071289
# Prediction data is: [113.001396]
# label data is:  [[120.]
#  [ 85.]
#  [ 72.]
#  [161.]
#  [ 96.]]
# epoch: 28 loss: 362.8744201660156
# Prediction data is: [127.44473]
# label data is:  [[122.]
#  [ 91.]
#  [ 26.]
#  [143.]
#  [146.]]
# epoch: 56 loss: 629.6023559570312
# Prediction data is: [92.06746]
# label data is:  [[ 29.5]
#  [ 47.5]
#  [ 59.5]
#  [ 27. ]
#  [140. ]]
# epoch: 84 loss: 1084.224609375
# Prediction data is: [127.99652]
# label data is:  [[137.5]
#  [111. ]
#  [ 67. ]
#  [108. ]
#  [155. ]]
# epoch: 112 loss: 1050.0419921875
# Prediction data is: [57.267796]
# label data is:  [[ 61. ]
#  [129. ]
#  [ 29. ]
#  [ 86. ]
#  [165.5]]
# epoch: 140 loss: 246.82774353027344
# Prediction data is: [123.66223]
# label data is:  [[126. ]
#  [ 26. ]
#  [ 22.5]
#  [ 74. ]
#  [ 75. ]]
# epoch: 168 loss: 138.77842712402344
# Prediction data is: [46.54309]
# label data is:  [[ 35.5]
#  [108. ]
#  [ 62. ]
#  [ 36. ]
#  [ 68. ]]
# epoch: 196 loss: 154.09228515625
# Prediction data is: [63.60677]
# label data is:  [[ 54. ]
#  [102. ]
#  [ 28. ]
#  [ 81.5]
#  [ 56.5]]
# epoch: 224 loss: 466.113525390625
# Prediction data is: [39.310303]
# label data is:  [[45.]
#  [94.]
#  [39.]
#  [58.]
#  [37.]]
# epoch: 252 loss: 394.18316650390625
# Prediction data is: [31.679619]
# label data is:  [[ 35.]
#  [ 95.]
#  [100.]
#  [ 74.]
#  [178.]]
# epoch: 280 loss: 997.3134765625
# Prediction data is: [95.20321]
# label data is:  [[150. ]
#  [119. ]
#  [ 45.5]
#  [ 20. ]
#  [ 40.5]]
# epoch: 308 loss: 879.2548828125
# Prediction data is: [95.10938]
# label data is:  [[124. ]
#  [ 41.5]
#  [ 34. ]
#  [138. ]
#  [ 48. ]]
# epoch: 336 loss: 687.9210205078125
# Prediction data is: [90.9397]
# label data is:  [[ 92.]
#  [124.]
#  [ 63.]
#  [116.]
#  [ 81.]]
# epoch: 364 loss: 116.35267639160156
# Prediction data is: [118.57069]
# label data is:  [[116.5]
#  [ 78. ]
#  [132. ]
#  [ 96. ]
#  [ 56.5]]
# epoch: 392 loss: 121.24492645263672
# Prediction data is: [93.818886]
# label data is:  [[ 61. ]
#  [ 82. ]
#  [144.5]
#  [ 65. ]
#  [107. ]]
# epoch: 420 loss: 395.10650634765625
# Prediction data is: [147.87616]
# label data is:  [[124. ]
#  [154. ]
#  [ 97.5]
#  [ 38. ]
#  [ 50. ]]
# epoch: 448 loss: 341.4627380371094
# Prediction data is: [89.383255]
# label data is:  [[ 52.]
#  [ 40.]
#  [170.]
#  [127.]
#  [154.]]
# epoch: 476 loss: 780.6220092773438
# Prediction data is: [101.70035]
# label data is:  [[ 76. ]
#  [ 72. ]
#  [111. ]
#  [140.5]
#  [133. ]]
# epoch: 504 loss: 383.988525390625
# Prediction data is: [63.234516]
# label data is:  [[ 42. ]
#  [164. ]
#  [ 49.5]
#  [133. ]
#  [118. ]]
# epoch: 532 loss: 441.46044921875
# Prediction data is: [93.21994]
# label data is:  [[88. ]
#  [95.5]
#  [52. ]
#  [20.5]
#  [79. ]]
# epoch: 560 loss: 591.83447265625
# Prediction data is: [132.20662]
# label data is:  [[107. ]
#  [140. ]
#  [ 43. ]
#  [ 24.5]
#  [ 49.5]]
# epoch: 588 loss: 741.9979858398438
# Prediction data is: [79.40655]
# label data is:  [[ 77.]
#  [ 51.]
#  [158.]
#  [ 72.]
#  [135.]]
# epoch: 616 loss: 283.1213073730469
# Prediction data is: [121.181015]
# label data is:  [[166. ]
#  [ 44. ]
#  [172.5]
#  [135. ]
#  [ 25. ]]
# epoch: 644 loss: 664.8959350585938
# Prediction data is: [125.6574]
# label data is:  [[146. ]
#  [160. ]
#  [105.5]
#  [ 47. ]
#  [ 30. ]]
# epoch: 672 loss: 222.7218780517578
# Prediction data is: [92.67201]
# label data is:  [[130.]
#  [ 28.]
#  [146.]
#  [ 83.]
#  [ 99.]]
# epoch: 700 loss: 745.26513671875
# Prediction data is: [41.213593]
# label data is:  [[ 59. ]
#  [ 81. ]
#  [175. ]
#  [ 45.5]
#  [110. ]]
# epoch: 728 loss: 248.19229125976562
# Prediction data is: [112.77785]
# label data is:  [[ 68. ]
#  [ 55. ]
#  [150.5]
#  [ 64. ]
#  [ 59. ]]
# epoch: 756 loss: 1015.1375122070312
# Prediction data is: [102.70203]
# label data is:  [[ 92.]
#  [103.]
#  [  8.]
#  [ 90.]
#  [115.]]
# epoch: 784 loss: 570.40869140625
# Prediction data is: [105.69876]
# label data is:  [[ 86. ]
#  [ 66. ]
#  [ 80.5]
#  [113.5]
#  [ 42. ]]
# epoch: 812 loss: 822.240234375
# Prediction data is: [162.99945]
# label data is:  [[165.]
#  [ 90.]
#  [ 97.]
#  [105.]]
# epoch: 840 loss: 141.18251037597656
# For epoch 29 the test accuracy over the whole test set is 0 %
# Prediction data is: [12.239111]
# label data is:  [[ 30.]
#  [155.]
#  [ 25.]
#  [ 95.]
#  [ 44.]]
# epoch: 0 loss: 682.9302368164062
# Prediction data is: [96.404564]
# label data is:  [[118. ]
#  [133. ]
#  [ 80.5]
#  [ 50. ]
#  [166. ]]
# epoch: 29 loss: 933.7637939453125
# Prediction data is: [32.535286]
# label data is:  [[ 63.]
#  [160.]
#  [  0.]
#  [150.]
#  [ 55.]]
# epoch: 58 loss: 321.46685791015625
# Prediction data is: [137.4317]
# label data is:  [[170. ]
#  [116. ]
#  [ 96. ]
#  [ 81.5]
#  [165.5]]
# epoch: 87 loss: 368.2892150878906
# Prediction data is: [157.52245]
# label data is:  [[127. ]
#  [ 92. ]
#  [ 47.5]
#  [ 61. ]
#  [ 68. ]]
# epoch: 116 loss: 280.3378601074219
# Prediction data is: [70.358185]
# label data is:  [[140.]
#  [ 52.]
#  [ 96.]
#  [102.]
#  [ 26.]]
# epoch: 145 loss: 1217.7276611328125
# Prediction data is: [74.561966]
# label data is:  [[ 52.]
#  [107.]
#  [ 92.]
#  [ 97.]
#  [ 59.]]
# epoch: 174 loss: 414.3507995605469
# Prediction data is: [90.80604]
# label data is:  [[ 95.5]
#  [ 90. ]
#  [ 45.5]
#  [133. ]
#  [ 64. ]]
# epoch: 203 loss: 584.6429443359375
# Prediction data is: [66.4815]
# label data is:  [[ 56.5]
#  [ 86. ]
#  [ 83. ]
#  [119. ]
#  [ 99. ]]
# epoch: 232 loss: 290.0153503417969
# Prediction data is: [128.60721]
# label data is:  [[146. ]
#  [154. ]
#  [103. ]
#  [172.5]
#  [ 39. ]]
# epoch: 261 loss: 91.9934310913086
# Prediction data is: [64.515114]
# label data is:  [[ 62.]
#  [146.]
#  [ 72.]
#  [ 81.]
#  [108.]]
# epoch: 290 loss: 491.4738464355469
# Prediction data is: [38.728275]
# label data is:  [[ 24.5]
#  [120. ]
#  [ 29.5]
#  [107. ]
#  [100. ]]
# epoch: 319 loss: 1036.9222412109375
# Prediction data is: [156.85382]
# label data is:  [[144.5]
#  [ 72. ]
#  [ 51. ]
#  [ 42. ]
#  [ 79. ]]
# epoch: 348 loss: 191.17076110839844
# Prediction data is: [60.504295]
# label data is:  [[56.5]
#  [76. ]
#  [26. ]
#  [74. ]
#  [ 8. ]]
# epoch: 377 loss: 523.8296508789062
# Prediction data is: [116.6709]
# label data is:  [[111. ]
#  [116.5]
#  [ 38. ]
#  [165. ]
#  [105. ]]
# epoch: 406 loss: 367.608154296875
# Prediction data is: [72.122986]
# label data is:  [[ 82.]
#  [ 77.]
#  [ 61.]
#  [110.]
#  [138.]]
# epoch: 435 loss: 508.9700622558594
# Prediction data is: [80.522026]
# label data is:  [[108. ]
#  [ 67. ]
#  [ 20.5]
#  [132. ]
#  [ 90. ]]
# epoch: 464 loss: 458.39892578125
# Prediction data is: [67.250595]
# label data is:  [[ 49.5]
#  [175. ]
#  [ 40. ]
#  [ 20. ]
#  [129. ]]
# epoch: 493 loss: 169.3695526123047
# Prediction data is: [73.463394]
# label data is:  [[ 65.]
#  [122.]
#  [124.]
#  [ 84.]
#  [126.]]
# epoch: 522 loss: 129.4505615234375
# Prediction data is: [151.58246]
# label data is:  [[113.5]
#  [ 41.5]
#  [ 78. ]
#  [164. ]
#  [ 81. ]]
# epoch: 551 loss: 570.6240234375
# Prediction data is: [108.70029]
# label data is:  [[111. ]
#  [ 45.5]
#  [ 72. ]
#  [154. ]
#  [ 74. ]]
# epoch: 580 loss: 1222.6822509765625
# Prediction data is: [75.35958]
# label data is:  [[47.]
#  [42.]
#  [37.]
#  [86.]
#  [34.]]
# epoch: 609 loss: 429.56451416015625
# Prediction data is: [56.18309]
# label data is:  [[ 58.]
#  [115.]
#  [124.]
#  [178.]
#  [ 48.]]
# epoch: 638 loss: 261.58306884765625
# Prediction data is: [74.30177]
# label data is:  [[ 85. ]
#  [ 59. ]
#  [150.5]
#  [ 59.5]
#  [105.5]]
# epoch: 667 loss: 1155.5848388671875
# Prediction data is: [54.20512]
# label data is:  [[ 35.5]
#  [130. ]
#  [135. ]
#  [ 97.5]
#  [ 45. ]]
# epoch: 696 loss: 1217.5570068359375
# Prediction data is: [111.89676]
# label data is:  [[158.]
#  [ 43.]
#  [ 75.]
#  [ 88.]
#  [ 37.]]
# epoch: 725 loss: 542.0958862304688
# Prediction data is: [90.72166]
# label data is:  [[135. ]
#  [137.5]
#  [ 54. ]
#  [ 94. ]
#  [143. ]]
# epoch: 754 loss: 2299.2783203125
# Prediction data is: [46.47352]
# label data is:  [[ 40.5]
#  [ 66. ]
#  [161. ]
#  [ 49.5]
#  [146. ]]
# epoch: 783 loss: 783.9728393554688
# Prediction data is: [53.177826]
# label data is:  [[ 36.]
#  [150.]
#  [ 35.]
#  [ 28.]
#  [124.]]
# epoch: 812 loss: 186.38333129882812
# Prediction data is: [119.295654]
# label data is:  [[140.5]
#  [ 22.5]
#  [ 33. ]
#  [ 68. ]
#  [ 91. ]]
# epoch: 841 loss: 950.8453979492188
# Prediction data is: [38.45806]
# label data is:  [[ 28.]
#  [ 29.]
#  [ 27.]
#  [140.]]
# epoch: 870 loss: 385.87469482421875
# For epoch 30 the test accuracy over the whole test set is 0 %
# Finished Training
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Finished Training
# (tensor([[ 53.5511],
#         [138.3569],
#         [ 50.6106],
#         [130.4083],
#         [ 78.4900]], device='cuda:0'), tensor([[ 44.0000],
#         [ 99.0000],
#         [ 31.5000],
#         [120.0000],
#         [101.0000]]))

# %%
print(predict(net, device))
# Out:
# (tensor([[ 78.4900],
#         [ 79.1134],
#         [ 82.1618],
#         [100.1420],
#         [ 53.5511]], device='cuda:0'), tensor([[101.],
#         [ 32.],
#         [105.],
#         [101.],
#         [ 44.]]))
